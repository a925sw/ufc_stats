# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
career_stats = pd.read_csv("data/career_fighter_stats.csv")
career_stats
# Out:
#       Unnamed: 0                 name      ufc_record      nickname   height  \
# 0              0            Tom Aaron           5-3-0           NaN       --
# 1              1         Danny Abbadi           4-6-0  THE ASSASSIN   5' 11"
# 2              2         David Abbott         10-15-0          TANK    6' 0"
# 3              3  Shamil Abdurakhimov          20-5-0         ABREK    6' 3"
# 4              4         Hiroyuki Abe   8-15-3 (1 NC)       ABE ANI    5' 6"
# ...          ...                  ...             ...           ...      ...
# 3670        3670        Dave Zitanick    5-7-0 (1 NC)           NaN       --
# 3671        3671          Alex Zuniga           6-3-0           NaN       --
# 3672        3672        George Zuniga           3-1-0           NaN    5' 9"
# 3673        3673         Allan Zuniga          13-1-0         TIGRE    5' 7"
# 3674        3674       Virgil Zwicker          15-6-1        REZDOG    6' 2"
#
#      reach  weight     stance            DOB  SLpM  SApM  Str_Acc_pct  \
# 0       --     0.0        NaN   Jul 13, 1978  0.00  0.00          0.0
# 1       --     0.0   Orthodox   Jul 03, 1983  3.29  4.41         38.0
# 2       --     0.0     Switch             --  1.35  3.55         30.0
# 3      76"     0.2   Orthodox   Sep 02, 1981  2.45  2.45         44.0
# 4       --     0.0   Orthodox             --  1.71  3.11         36.0
# ...    ...     ...        ...            ...   ...   ...          ...
# 3670    --     0.0        NaN   Mar 05, 1980  0.00  0.00          0.0
# 3671    --     0.0        NaN             --  0.00  0.00          0.0
# 3672    --     0.0        NaN             --  7.64  5.45         38.0
# 3673   70"     1.0   Orthodox   Apr 04, 1992  3.93  1.80         52.0
# 3674   74"     0.0        NaN   Jun 26, 1982  3.34  4.87         48.0
#
#       Str_Def_pct  TD_Avg  TD_Acc_pct  TD_Def_pct  Sub_Avg
# 0             0.0    0.00         0.0         0.0      0.0
# 1            57.0    0.00         0.0        77.0      0.0
# 2            38.0    1.07        33.0        66.0      0.0
# 3            58.0    1.23        24.0        47.0      0.2
# 4            63.0    0.00         0.0        33.0      0.0
# ...           ...     ...         ...         ...      ...
# 3670          0.0    0.00         0.0         0.0      0.0
# 3671          0.0    0.00         0.0         0.0      0.0
# 3672         37.0    0.00         0.0       100.0      0.0
# 3673         61.0    0.00         0.0        57.0      1.0
# 3674         39.0    1.31        30.0        50.0      0.0
#
# [3675 rows x 17 columns]

# %%
career_stats = career_stats.drop(columns=["nickname", "Unnamed: 0"])
# career_stats = career_stats[career_stats["height"].str.contains("-")==False]
# career_stats = career_stats[career_stats["weight"].str.contains("-")==False]
# career_stats = career_stats[career_stats["DOB"].str.contains("-")==False]
career_stats
# Out:
#                      name      ufc_record   height reach  weight     stance  \
# 0               Tom Aaron           5-3-0       --    --     0.0        NaN
# 1            Danny Abbadi           4-6-0   5' 11"    --     0.0   Orthodox
# 2            David Abbott         10-15-0    6' 0"    --     0.0     Switch
# 3     Shamil Abdurakhimov          20-5-0    6' 3"   76"     0.2   Orthodox
# 4            Hiroyuki Abe   8-15-3 (1 NC)    5' 6"    --     0.0   Orthodox
# ...                   ...             ...      ...   ...     ...        ...
# 3670        Dave Zitanick    5-7-0 (1 NC)       --    --     0.0        NaN
# 3671          Alex Zuniga           6-3-0       --    --     0.0        NaN
# 3672        George Zuniga           3-1-0    5' 9"    --     0.0        NaN
# 3673         Allan Zuniga          13-1-0    5' 7"   70"     1.0   Orthodox
# 3674       Virgil Zwicker          15-6-1    6' 2"   74"     0.0        NaN
#
#                 DOB  SLpM  SApM  Str_Acc_pct  Str_Def_pct  TD_Avg  TD_Acc_pct  \
# 0      Jul 13, 1978  0.00  0.00          0.0          0.0    0.00         0.0
# 1      Jul 03, 1983  3.29  4.41         38.0         57.0    0.00         0.0
# 2                --  1.35  3.55         30.0         38.0    1.07        33.0
# 3      Sep 02, 1981  2.45  2.45         44.0         58.0    1.23        24.0
# 4                --  1.71  3.11         36.0         63.0    0.00         0.0
# ...             ...   ...   ...          ...          ...     ...         ...
# 3670   Mar 05, 1980  0.00  0.00          0.0          0.0    0.00         0.0
# 3671             --  0.00  0.00          0.0          0.0    0.00         0.0
# 3672             --  7.64  5.45         38.0         37.0    0.00         0.0
# 3673   Apr 04, 1992  3.93  1.80         52.0         61.0    0.00         0.0
# 3674   Jun 26, 1982  3.34  4.87         48.0         39.0    1.31        30.0
#
#       TD_Def_pct  Sub_Avg
# 0            0.0      0.0
# 1           77.0      0.0
# 2           66.0      0.0
# 3           47.0      0.2
# 4           33.0      0.0
# ...          ...      ...
# 3670         0.0      0.0
# 3671         0.0      0.0
# 3672       100.0      0.0
# 3673        57.0      1.0
# 3674        50.0      0.0
#
# [3675 rows x 15 columns]

# %%
fighter_info = career_stats[["name", "DOB", "ufc_record", "height", "weight", "reach", "stance"]]
fighter_info
# Out:
#                      name            DOB      ufc_record   height  weight  \
# 0               Tom Aaron   Jul 13, 1978           5-3-0       --     0.0
# 1            Danny Abbadi   Jul 03, 1983           4-6-0   5' 11"     0.0
# 2            David Abbott             --         10-15-0    6' 0"     0.0
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0    6' 3"     0.2
# 4            Hiroyuki Abe             --   8-15-3 (1 NC)    5' 6"     0.0
# ...                   ...            ...             ...      ...     ...
# 3670        Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)       --     0.0
# 3671          Alex Zuniga             --           6-3-0       --     0.0
# 3672        George Zuniga             --           3-1-0    5' 9"     0.0
# 3673         Allan Zuniga   Apr 04, 1992          13-1-0    5' 7"     1.0
# 3674       Virgil Zwicker   Jun 26, 1982          15-6-1    6' 2"     0.0
#
#      reach     stance
# 0       --        NaN
# 1       --   Orthodox
# 2       --     Switch
# 3      76"   Orthodox
# 4       --   Orthodox
# ...    ...        ...
# 3670    --        NaN
# 3671    --        NaN
# 3672    --        NaN
# 3673   70"   Orthodox
# 3674   74"        NaN
#
# [3675 rows x 7 columns]

# %%
no_height = fighter_info[fighter_info["height"].str.contains("-")]
no_height
# Out:
#                     name            DOB     ufc_record height  weight reach  \
# 0              Tom Aaron   Jul 13, 1978          5-3-0     --     0.0    --
# 35           Brett Albee             --          3-2-0     --     0.0    --
# 40    Israel Albuquerque             --          0-3-0     --     0.0    --
# 41           Juan Alcain             --          1-2-0     --     0.0    --
# 57           Levi Alford             --          1-7-0     --     0.0    --
# ...                  ...            ...            ...    ...     ...   ...
# 3633       Artenus Young   Jul 16, 1980        10-12-0     --     0.0    --
# 3646         Joao Zaiden   Mar 16, 1993         10-3-0     --     0.0    --
# 3665       Mike Zichelle             --          8-4-0     --     2.0    --
# 3670       Dave Zitanick   Mar 05, 1980   5-7-0 (1 NC)     --     0.0    --
# 3671         Alex Zuniga             --          6-3-0     --     0.0    --
#
#          stance
# 0           NaN
# 35          NaN
# 40     Orthodox
# 41          NaN
# 57          NaN
# ...         ...
# 3633        NaN
# 3646        NaN
# 3665        NaN
# 3670        NaN
# 3671        NaN
#
# [271 rows x 7 columns]

# %%
fighter_info = fighter_info[~fighter_info["height"].str.contains("-")]
fighter_info
# Out:
#                      name            DOB      ufc_record   height  weight  \
# 1            Danny Abbadi   Jul 03, 1983           4-6-0   5' 11"     0.0
# 2            David Abbott             --         10-15-0    6' 0"     0.0
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0    6' 3"     0.2
# 4            Hiroyuki Abe             --   8-15-3 (1 NC)    5' 6"     0.0
# 5              Daichi Abe   Nov 27, 1991           6-2-0   5' 11"     0.0
# ...                   ...            ...             ...      ...     ...
# 3668          Cat Zingano   Jul 01, 1982          10-4-0    5' 6"     0.8
# 3669        Igor Zinoviev             --           4-1-2    6' 1"     0.0
# 3672        George Zuniga             --           3-1-0    5' 9"     0.0
# 3673         Allan Zuniga   Apr 04, 1992          13-1-0    5' 7"     1.0
# 3674       Virgil Zwicker   Jun 26, 1982          15-6-1    6' 2"     0.0
#
#      reach     stance
# 1       --   Orthodox
# 2       --     Switch
# 3      76"   Orthodox
# 4       --   Orthodox
# 5      71"   Orthodox
# ...    ...        ...
# 3668   68"   Southpaw
# 3669    --   Orthodox
# 3672    --        NaN
# 3673   70"   Orthodox
# 3674   74"        NaN
#
# [3404 rows x 7 columns]

# %%
fighter_info[["height_feet", "height_inches"]] = fighter_info.height.str.split("'", expand=True)
fighter_info
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\frame.py:3065: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                      name            DOB      ufc_record   height  weight  \
# 1            Danny Abbadi   Jul 03, 1983           4-6-0   5' 11"     0.0
# 2            David Abbott             --         10-15-0    6' 0"     0.0
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0    6' 3"     0.2
# 4            Hiroyuki Abe             --   8-15-3 (1 NC)    5' 6"     0.0
# 5              Daichi Abe   Nov 27, 1991           6-2-0   5' 11"     0.0
# ...                   ...            ...             ...      ...     ...
# 3668          Cat Zingano   Jul 01, 1982          10-4-0    5' 6"     0.8
# 3669        Igor Zinoviev             --           4-1-2    6' 1"     0.0
# 3672        George Zuniga             --           3-1-0    5' 9"     0.0
# 3673         Allan Zuniga   Apr 04, 1992          13-1-0    5' 7"     1.0
# 3674       Virgil Zwicker   Jun 26, 1982          15-6-1    6' 2"     0.0
#
#      reach     stance height_feet height_inches
# 1       --   Orthodox           5           11"
# 2       --     Switch           6            0"
# 3      76"   Orthodox           6            3"
# 4       --   Orthodox           5            6"
# 5      71"   Orthodox           5           11"
# ...    ...        ...         ...           ...
# 3668   68"   Southpaw           5            6"
# 3669    --   Orthodox           6            1"
# 3672    --        NaN           5            9"
# 3673   70"   Orthodox           5            7"
# 3674   74"        NaN           6            2"
#
# [3404 rows x 9 columns]

# %%
fighter_info["height_inches"] = fighter_info["height_inches"].str.strip('"')
fighter_info["height_feet"] = fighter_info["height_feet"].astype(int)
fighter_info["height_inches"] = fighter_info["height_inches"].astype(int)
fighter_info
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                      name            DOB      ufc_record   height  weight  \
# 1            Danny Abbadi   Jul 03, 1983           4-6-0   5' 11"     0.0
# 2            David Abbott             --         10-15-0    6' 0"     0.0
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0    6' 3"     0.2
# 4            Hiroyuki Abe             --   8-15-3 (1 NC)    5' 6"     0.0
# 5              Daichi Abe   Nov 27, 1991           6-2-0   5' 11"     0.0
# ...                   ...            ...             ...      ...     ...
# 3668          Cat Zingano   Jul 01, 1982          10-4-0    5' 6"     0.8
# 3669        Igor Zinoviev             --           4-1-2    6' 1"     0.0
# 3672        George Zuniga             --           3-1-0    5' 9"     0.0
# 3673         Allan Zuniga   Apr 04, 1992          13-1-0    5' 7"     1.0
# 3674       Virgil Zwicker   Jun 26, 1982          15-6-1    6' 2"     0.0
#
#      reach     stance  height_feet  height_inches
# 1       --   Orthodox            5             11
# 2       --     Switch            6              0
# 3      76"   Orthodox            6              3
# 4       --   Orthodox            5              6
# 5      71"   Orthodox            5             11
# ...    ...        ...          ...            ...
# 3668   68"   Southpaw            5              6
# 3669    --   Orthodox            6              1
# 3672    --        NaN            5              9
# 3673   70"   Orthodox            5              7
# 3674   74"        NaN            6              2
#
# [3404 rows x 9 columns]

# %%
fighter_info["height_in"] = (fighter_info["height_feet"] * 12) + fighter_info["height_inches"]
fighter_info
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                      name            DOB      ufc_record   height  weight  \
# 1            Danny Abbadi   Jul 03, 1983           4-6-0   5' 11"     0.0
# 2            David Abbott             --         10-15-0    6' 0"     0.0
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0    6' 3"     0.2
# 4            Hiroyuki Abe             --   8-15-3 (1 NC)    5' 6"     0.0
# 5              Daichi Abe   Nov 27, 1991           6-2-0   5' 11"     0.0
# ...                   ...            ...             ...      ...     ...
# 3668          Cat Zingano   Jul 01, 1982          10-4-0    5' 6"     0.8
# 3669        Igor Zinoviev             --           4-1-2    6' 1"     0.0
# 3672        George Zuniga             --           3-1-0    5' 9"     0.0
# 3673         Allan Zuniga   Apr 04, 1992          13-1-0    5' 7"     1.0
# 3674       Virgil Zwicker   Jun 26, 1982          15-6-1    6' 2"     0.0
#
#      reach     stance  height_feet  height_inches  height_in
# 1       --   Orthodox            5             11         71
# 2       --     Switch            6              0         72
# 3      76"   Orthodox            6              3         75
# 4       --   Orthodox            5              6         66
# 5      71"   Orthodox            5             11         71
# ...    ...        ...          ...            ...        ...
# 3668   68"   Southpaw            5              6         66
# 3669    --   Orthodox            6              1         73
# 3672    --        NaN            5              9         69
# 3673   70"   Orthodox            5              7         67
# 3674   74"        NaN            6              2         74
#
# [3404 rows x 10 columns]

# %%
fighter_info = fighter_info.drop(columns=["height", "height_feet", "height_inches"])
fighter_info
# Out:
#                      name            DOB      ufc_record  weight reach  \
# 1            Danny Abbadi   Jul 03, 1983           4-6-0     0.0    --
# 2            David Abbott             --         10-15-0     0.0    --
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0     0.2   76"
# 4            Hiroyuki Abe             --   8-15-3 (1 NC)     0.0    --
# 5              Daichi Abe   Nov 27, 1991           6-2-0     0.0   71"
# ...                   ...            ...             ...     ...   ...
# 3668          Cat Zingano   Jul 01, 1982          10-4-0     0.8   68"
# 3669        Igor Zinoviev             --           4-1-2     0.0    --
# 3672        George Zuniga             --           3-1-0     0.0    --
# 3673         Allan Zuniga   Apr 04, 1992          13-1-0     1.0   70"
# 3674       Virgil Zwicker   Jun 26, 1982          15-6-1     0.0   74"
#
#          stance  height_in
# 1      Orthodox         71
# 2        Switch         72
# 3      Orthodox         75
# 4      Orthodox         66
# 5      Orthodox         71
# ...         ...        ...
# 3668   Southpaw         66
# 3669   Orthodox         73
# 3672        NaN         69
# 3673   Orthodox         67
# 3674        NaN         74
#
# [3404 rows x 7 columns]

# %%
fighter_info["reach"] = fighter_info["reach"].str.strip('"')
fighter_info
# Out:
#                      name            DOB      ufc_record  weight reach  \
# 1            Danny Abbadi   Jul 03, 1983           4-6-0     0.0    --
# 2            David Abbott             --         10-15-0     0.0    --
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0     0.2    76
# 4            Hiroyuki Abe             --   8-15-3 (1 NC)     0.0    --
# 5              Daichi Abe   Nov 27, 1991           6-2-0     0.0    71
# ...                   ...            ...             ...     ...   ...
# 3668          Cat Zingano   Jul 01, 1982          10-4-0     0.8    68
# 3669        Igor Zinoviev             --           4-1-2     0.0    --
# 3672        George Zuniga             --           3-1-0     0.0    --
# 3673         Allan Zuniga   Apr 04, 1992          13-1-0     1.0    70
# 3674       Virgil Zwicker   Jun 26, 1982          15-6-1     0.0    74
#
#          stance  height_in
# 1      Orthodox         71
# 2        Switch         72
# 3      Orthodox         75
# 4      Orthodox         66
# 5      Orthodox         71
# ...         ...        ...
# 3668   Southpaw         66
# 3669   Orthodox         73
# 3672        NaN         69
# 3673   Orthodox         67
# 3674        NaN         74
#
# [3404 rows x 7 columns]

# %%
no_reach = fighter_info[fighter_info["reach"].str.contains("-")]
no_reach
# Out:
#                  name            DOB      ufc_record  weight reach     stance  \
# 1        Danny Abbadi   Jul 03, 1983           4-6-0     0.0    --   Orthodox
# 2        David Abbott             --         10-15-0     0.0    --     Switch
# 4        Hiroyuki Abe             --   8-15-3 (1 NC)     0.0    --   Orthodox
# 6          Papy Abedi   Jun 30, 1978          10-4-0     1.3    --   Southpaw
# 7       Ricardo Abreu   Apr 27, 1984           5-1-0     0.7    --   Orthodox
# ...               ...            ...             ...     ...   ...        ...
# 3661      Zhifa Shang             --          22-7-0     0.0    --        NaN
# 3666      James Zikic   Mar 01, 1977         21-10-2     0.5    --   Orthodox
# 3667  Errol Zimmerman   Apr 20, 1986           0-1-0     0.0    --   Orthodox
# 3669    Igor Zinoviev             --           4-1-2     0.0    --   Orthodox
# 3672    George Zuniga             --           3-1-0     0.0    --        NaN
#
#       height_in
# 1            71
# 2            72
# 4            66
# 6            71
# 7            71
# ...         ...
# 3661         66
# 3666         74
# 3667         75
# 3669         73
# 3672         69
#
# [1699 rows x 7 columns]

# %%
reach = fighter_info[~fighter_info["reach"].str.contains("-")]
reach
# Out:
#                      name            DOB      ufc_record  weight reach  \
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0     0.2    76
# 5              Daichi Abe   Nov 27, 1991           6-2-0     0.0    71
# 8           Klidson Abreu   Dec 24, 1992   15-4-0 (1 NC)     0.0    74
# 11             Juan Adams   Jan 16, 1992           5-3-0     0.0    80
# 12          Anthony Adams   Jan 13, 1988           8-2-0     0.0    76
# ...                   ...            ...             ...     ...   ...
# 3663   Zhalgas Zhumagulov   Aug 29, 1988          14-5-0     0.5    66
# 3664           Fares Ziam   Mar 21, 1997          12-3-0     0.0    75
# 3668          Cat Zingano   Jul 01, 1982          10-4-0     0.8    68
# 3673         Allan Zuniga   Apr 04, 1992          13-1-0     1.0    70
# 3674       Virgil Zwicker   Jun 26, 1982          15-6-1     0.0    74
#
#          stance  height_in
# 3      Orthodox         75
# 5      Orthodox         71
# 8      Orthodox         72
# 11     Orthodox         77
# 12     Orthodox         73
# ...         ...        ...
# 3663     Switch         64
# 3664   Orthodox         73
# 3668   Southpaw         66
# 3673   Orthodox         67
# 3674        NaN         74
#
# [1705 rows x 7 columns]

# %%
no_reach["reach"] = no_reach["height_in"]
no_reach
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                  name            DOB      ufc_record  weight  reach  \
# 1        Danny Abbadi   Jul 03, 1983           4-6-0     0.0     71
# 2        David Abbott             --         10-15-0     0.0     72
# 4        Hiroyuki Abe             --   8-15-3 (1 NC)     0.0     66
# 6          Papy Abedi   Jun 30, 1978          10-4-0     1.3     71
# 7       Ricardo Abreu   Apr 27, 1984           5-1-0     0.7     71
# ...               ...            ...             ...     ...    ...
# 3661      Zhifa Shang             --          22-7-0     0.0     66
# 3666      James Zikic   Mar 01, 1977         21-10-2     0.5     74
# 3667  Errol Zimmerman   Apr 20, 1986           0-1-0     0.0     75
# 3669    Igor Zinoviev             --           4-1-2     0.0     73
# 3672    George Zuniga             --           3-1-0     0.0     69
#
#          stance  height_in
# 1      Orthodox         71
# 2        Switch         72
# 4      Orthodox         66
# 6      Southpaw         71
# 7      Orthodox         71
# ...         ...        ...
# 3661        NaN         66
# 3666   Orthodox         74
# 3667   Orthodox         75
# 3669   Orthodox         73
# 3672        NaN         69
#
# [1699 rows x 7 columns]

# %%
frames = [reach, no_reach]
fighter_df = pd.concat(frames)
fighter_df
# Out:
#                      name            DOB      ufc_record  weight reach  \
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0     0.2    76
# 5              Daichi Abe   Nov 27, 1991           6-2-0     0.0    71
# 8           Klidson Abreu   Dec 24, 1992   15-4-0 (1 NC)     0.0    74
# 11             Juan Adams   Jan 16, 1992           5-3-0     0.0    80
# 12          Anthony Adams   Jan 13, 1988           8-2-0     0.0    76
# ...                   ...            ...             ...     ...   ...
# 3661          Zhifa Shang             --          22-7-0     0.0    66
# 3666          James Zikic   Mar 01, 1977         21-10-2     0.5    74
# 3667      Errol Zimmerman   Apr 20, 1986           0-1-0     0.0    75
# 3669        Igor Zinoviev             --           4-1-2     0.0    73
# 3672        George Zuniga             --           3-1-0     0.0    69
#
#          stance  height_in
# 3      Orthodox         75
# 5      Orthodox         71
# 8      Orthodox         72
# 11     Orthodox         77
# 12     Orthodox         73
# ...         ...        ...
# 3661        NaN         66
# 3666   Orthodox         74
# 3667   Orthodox         75
# 3669   Orthodox         73
# 3672        NaN         69
#
# [3404 rows x 7 columns]

# %%
fighter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3404 entries, 3 to 3672
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3404 non-null   object
#  1   DOB         3404 non-null   object
#  2   ufc_record  3404 non-null   object
#  3   weight      3404 non-null   float64
#  4   reach       3404 non-null   object
#  5   stance      2784 non-null   object
#  6   height_in   3404 non-null   int32
# dtypes: float64(1), int32(1), object(5)
# memory usage: 199.5+ KB

# %%
fighter_df["reach"] = fighter_df["reach"].astype(int)
fighter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3404 entries, 3 to 3672
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3404 non-null   object
#  1   DOB         3404 non-null   object
#  2   ufc_record  3404 non-null   object
#  3   weight      3404 non-null   float64
#  4   reach       3404 non-null   int32
#  5   stance      2784 non-null   object
#  6   height_in   3404 non-null   int32
# dtypes: float64(1), int32(2), object(4)
# memory usage: 186.2+ KB

# %%
fighter_df["stance"].value_counts()
# Out:
#  Orthodox       2155
#  Southpaw        492
#  Switch          127
#  Open Stance       7
#  Sideways          3
# Name: stance, dtype: int64

# %%
fighter_df["stance"] = fighter_df["stance"].astype(str)

# %%
fighter_df["stance"] = fighter_df["stance"].replace({"nan" : "Orthodox"})
fighter_df["stance"] = fighter_df["stance"].replace({" Orthodox" : "Orthodox"})
fighter_df["stance"] = fighter_df["stance"].replace({" Southpaw" : "Southpaw"})
fighter_df["stance"] = fighter_df["stance"].replace({" Switch" : "Switch"})
fighter_df["stance"] = fighter_df["stance"].replace({" Open Stance" : "Switch"})
fighter_df["stance"] = fighter_df["stance"].replace({" Sideways" : "Switch"})
fighter_df["stance"].value_counts()
# Out:
# Orthodox    2775
# Southpaw     492
# Switch       137
# Name: stance, dtype: int64

# %%
fighter_df["weight"].value_counts()
# Out:
# 0.0    1844
# 0.5     118
# 0.4     117
# 1.0     106
# 0.3     103
#        ...
# 7.7       1
# 7.4       1
# 6.9       1
# 8.1       1
# 9.6       1
# Name: weight, Length: 93, dtype: int64

# %%
fighter_df["weight"].isna().sum()
# Out:
# 0

# %%
fighter_df
# Out:
#                      name            DOB      ufc_record  weight  reach  \
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0     0.2     76
# 5              Daichi Abe   Nov 27, 1991           6-2-0     0.0     71
# 8           Klidson Abreu   Dec 24, 1992   15-4-0 (1 NC)     0.0     74
# 11             Juan Adams   Jan 16, 1992           5-3-0     0.0     80
# 12          Anthony Adams   Jan 13, 1988           8-2-0     0.0     76
# ...                   ...            ...             ...     ...    ...
# 3661          Zhifa Shang             --          22-7-0     0.0     66
# 3666          James Zikic   Mar 01, 1977         21-10-2     0.5     74
# 3667      Errol Zimmerman   Apr 20, 1986           0-1-0     0.0     75
# 3669        Igor Zinoviev             --           4-1-2     0.0     73
# 3672        George Zuniga             --           3-1-0     0.0     69
#
#         stance  height_in
# 3     Orthodox         75
# 5     Orthodox         71
# 8     Orthodox         72
# 11    Orthodox         77
# 12    Orthodox         73
# ...        ...        ...
# 3661  Orthodox         66
# 3666  Orthodox         74
# 3667  Orthodox         75
# 3669  Orthodox         73
# 3672  Orthodox         69
#
# [3404 rows x 7 columns]

# %%
no_dob = fighter_df[fighter_df["DOB"].str.contains("-")]
no_dob
# Out:
#                   name  DOB      ufc_record  weight  reach    stance  \
# 890         Per Eklund   --          14-5-1     3.6     72  Orthodox
# 1856      Jess Liaudin   --         20-11-0     1.6     72  Orthodox
# 3502    Curt Warburton   --          13-6-0     0.9     73  Orthodox
# 2         David Abbott   --         10-15-0     0.0     72    Switch
# 4         Hiroyuki Abe   --   8-15-3 (1 NC)     0.0     66  Orthodox
# ...                ...  ...             ...     ...    ...       ...
# 3654  Daniel Zellhuber   --          10-0-0     0.0     73  Orthodox
# 3657   Carlos Zevallos   --           3-4-0     0.0     72  Orthodox
# 3661       Zhifa Shang   --          22-7-0     0.0     66  Orthodox
# 3669     Igor Zinoviev   --           4-1-2     0.0     73  Orthodox
# 3672     George Zuniga   --           3-1-0     0.0     69  Orthodox
#
#       height_in
# 890          70
# 1856         69
# 3502         72
# 2            72
# 4            66
# ...         ...
# 3654         73
# 3657         72
# 3661         66
# 3669         73
# 3672         69
#
# [542 rows x 7 columns]

# %%
clean_fighter_df = fighter_df[~fighter_df["DOB"].str.contains("-")]

# %%
clean_fighter_df.to_csv("data/clean_fighter_info.csv")
clean_fighter_df
# Out:
#                      name            DOB      ufc_record  weight  reach  \
# 3     Shamil Abdurakhimov   Sep 02, 1981          20-5-0     0.2     76
# 5              Daichi Abe   Nov 27, 1991           6-2-0     0.0     71
# 8           Klidson Abreu   Dec 24, 1992   15-4-0 (1 NC)     0.0     74
# 11             Juan Adams   Jan 16, 1992           5-3-0     0.0     80
# 12          Anthony Adams   Jan 13, 1988           8-2-0     0.0     76
# ...                   ...            ...             ...     ...    ...
# 3653        Joao Zeferino   Jan 15, 1986          21-9-0     1.0     71
# 3655        Craig Zellner   Sep 09, 1976           4-3-0     0.0     74
# 3656        Roman Zentsov   Sep 10, 1973         18-12-0     3.2     73
# 3666          James Zikic   Mar 01, 1977         21-10-2     0.5     74
# 3667      Errol Zimmerman   Apr 20, 1986           0-1-0     0.0     75
#
#         stance  height_in
# 3     Orthodox         75
# 5     Orthodox         71
# 8     Orthodox         72
# 11    Orthodox         77
# 12    Orthodox         73
# ...        ...        ...
# 3653  Orthodox         71
# 3655  Orthodox         74
# 3656  Orthodox         73
# 3666  Orthodox         74
# 3667  Orthodox         75
#
# [2862 rows x 7 columns]
