# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import feature_extraction, model_selection, naive_bayes, pipeline, manifold, preprocessing, metrics
from tensorflow.keras import models, layers, preprocessing as kprocessing
from tensorflow.keras import backend as K
from sklearn.preprocessing import LabelEncoder

# %%
cumulative_df = pd.read_csv("data/big_df.csv")
cumulative_df
# Out:
#       lev1  blue_heightIN  red_heightIN       blue_name          red_name  \
# 0        0           68.0          68.0  Cody Garbrandt          Rob Font
# 1        1           68.0          68.0  Cody Garbrandt     Dominick Cruz
# 2        2           68.0          67.0  Cody Garbrandt    Thomas Almeida
# 3        3           68.0          65.0  Cody Garbrandt  Raphael Assuncao
# 4        4           68.0          66.0  Cody Garbrandt      TJ Dillashaw
# ...    ...            ...           ...             ...               ...
# 5789  5789           75.0          73.0      Sam Adkins          Don Frye
# 5790  5790           72.0          74.0   Oleg Taktarov        Dan Severn
# 5791  5791           72.0          74.0   Oleg Taktarov        Dan Severn
# 5792  5792           70.0          73.0   Ron van Clief      Royce Gracie
# 5793  5793           74.0          73.0   Patrick Smith      Royce Gracie
#
#       blue_reach  red_reach blue_stance red_stance  blue_weight  ...  \
# 0           65.0       71.0    Orthodox   Orthodox          135  ...
# 1           65.0       68.0    Orthodox   Orthodox          135  ...
# 2           65.0       70.0    Orthodox   Southpaw          135  ...
# 3           65.0       66.0    Orthodox   Orthodox          135  ...
# 4           65.0       67.0    Orthodox   Orthodox          135  ...
# ...          ...        ...         ...        ...          ...  ...
# 5789        75.0       73.0    Orthodox   Orthodox          225  ...
# 5790        72.0       74.0    Orthodox   Southpaw          210  ...
# 5791        72.0       74.0    Orthodox   Southpaw          210  ...
# 5792        70.0       73.0    Orthodox   Southpaw          190  ...
# 5793        74.0       73.0    Orthodox   Southpaw          225  ...
#
#       blue_total_stk_abs_per_min  blue_sig_stk_abs_per_min  \
# 0                       3.652951                  3.328989
# 1                       3.595970                  3.254973
# 2                       3.601947                  3.244997
# 3                       3.969022                  3.543078
# 4                       3.243243                  2.906283
# ...                          ...                       ...
# 5789                    0.000000                  0.000000
# 5790                    8.735632                  2.068966
# 5791                    0.000000                  0.000000
# 5792                    0.000000                  0.000000
# 5793                    0.000000                  0.000000
#
#       blue_total_stk_per_min_diff  blue_sig_stk_per_min_diff  \
# 0                       -0.167567                   0.022342
# 1                        0.139499                   0.340997
# 2                       -0.048675                   0.178475
# 3                       -0.116167                   0.174250
# 4                        0.589681                   0.779221
# ...                           ...                        ...
# 5789                     0.000000                   0.000000
# 5790                    -8.735632                  -2.068966
# 5791                     0.000000                   0.000000
# 5792                     0.000000                   0.000000
# 5793                     0.000000                   0.000000
#
#       blue_ctrl_sec_per_min  blue_ctrld_sec_per_min  blue_ctrl_diff  \
# 0                  1.630981                0.837833        0.793148
# 1                  1.658486                1.146990        0.511496
# 2                  1.703624                1.200649        0.502975
# 3                  1.974831                1.432720        0.542110
# 4                  2.148122                0.947701        1.200421
# ...                     ...                     ...             ...
# 5789               0.000000                0.000000        0.000000
# 5790               0.000000                0.000000        0.000000
# 5791               0.000000                0.000000        0.000000
# 5792               0.000000                0.000000        0.000000
# 5793               0.000000                0.000000        0.000000
#
#       blue_TD_acc  blue_TD_def  blue_KDs_per_100_stk
# 0        0.333333        100.0              3.333333
# 1        0.363636        100.0              3.448276
# 2        0.363636        100.0              3.317536
# 3        0.363636        100.0              3.125000
# 4        0.444444        100.0              3.428571
# ...           ...          ...                   ...
# 5789     0.000000          0.0              0.000000
# 5790     0.000000         99.0              0.000000
# 5791     0.000000          0.0              0.000000
# 5792     0.000000          0.0              0.000000
# 5793     0.000000          0.0              0.000000
#
# [5794 rows x 145 columns]

# %%
cleaned_fights = pd.read_csv("data/all_fights_data.csv")
winners = cleaned_fights["winner"]
cumulative_df["winner"] = winners
cumulative_df
# Out:
#       lev1  blue_heightIN  red_heightIN       blue_name          red_name  \
# 0        0           68.0          68.0  Cody Garbrandt          Rob Font
# 1        1           68.0          68.0  Cody Garbrandt     Dominick Cruz
# 2        2           68.0          67.0  Cody Garbrandt    Thomas Almeida
# 3        3           68.0          65.0  Cody Garbrandt  Raphael Assuncao
# 4        4           68.0          66.0  Cody Garbrandt      TJ Dillashaw
# ...    ...            ...           ...             ...               ...
# 5789  5789           75.0          73.0      Sam Adkins          Don Frye
# 5790  5790           72.0          74.0   Oleg Taktarov        Dan Severn
# 5791  5791           72.0          74.0   Oleg Taktarov        Dan Severn
# 5792  5792           70.0          73.0   Ron van Clief      Royce Gracie
# 5793  5793           74.0          73.0   Patrick Smith      Royce Gracie
#
#       blue_reach  red_reach blue_stance red_stance  blue_weight  ...  \
# 0           65.0       71.0    Orthodox   Orthodox          135  ...
# 1           65.0       68.0    Orthodox   Orthodox          135  ...
# 2           65.0       70.0    Orthodox   Southpaw          135  ...
# 3           65.0       66.0    Orthodox   Orthodox          135  ...
# 4           65.0       67.0    Orthodox   Orthodox          135  ...
# ...          ...        ...         ...        ...          ...  ...
# 5789        75.0       73.0    Orthodox   Orthodox          225  ...
# 5790        72.0       74.0    Orthodox   Southpaw          210  ...
# 5791        72.0       74.0    Orthodox   Southpaw          210  ...
# 5792        70.0       73.0    Orthodox   Southpaw          190  ...
# 5793        74.0       73.0    Orthodox   Southpaw          225  ...
#
#       blue_sig_stk_abs_per_min  blue_total_stk_per_min_diff  \
# 0                     3.328989                    -0.167567
# 1                     3.254973                     0.139499
# 2                     3.244997                    -0.048675
# 3                     3.543078                    -0.116167
# 4                     2.906283                     0.589681
# ...                        ...                          ...
# 5789                  0.000000                     0.000000
# 5790                  2.068966                    -8.735632
# 5791                  0.000000                     0.000000
# 5792                  0.000000                     0.000000
# 5793                  0.000000                     0.000000
#
#       blue_sig_stk_per_min_diff  blue_ctrl_sec_per_min  \
# 0                      0.022342               1.630981
# 1                      0.340997               1.658486
# 2                      0.178475               1.703624
# 3                      0.174250               1.974831
# 4                      0.779221               2.148122
# ...                         ...                    ...
# 5789                   0.000000               0.000000
# 5790                  -2.068966               0.000000
# 5791                   0.000000               0.000000
# 5792                   0.000000               0.000000
# 5793                   0.000000               0.000000
#
#       blue_ctrld_sec_per_min  blue_ctrl_diff  blue_TD_acc  blue_TD_def  \
# 0                   0.837833        0.793148     0.333333        100.0
# 1                   1.146990        0.511496     0.363636        100.0
# 2                   1.200649        0.502975     0.363636        100.0
# 3                   1.432720        0.542110     0.363636        100.0
# 4                   0.947701        1.200421     0.444444        100.0
# ...                      ...             ...          ...          ...
# 5789                0.000000        0.000000     0.000000          0.0
# 5790                0.000000        0.000000     0.000000         99.0
# 5791                0.000000        0.000000     0.000000          0.0
# 5792                0.000000        0.000000     0.000000          0.0
# 5793                0.000000        0.000000     0.000000          0.0
#
#       blue_KDs_per_100_stk  winner
# 0                 3.333333     red
# 1                 3.448276    blue
# 2                 3.317536    blue
# 3                 3.125000    blue
# 4                 3.428571     red
# ...                    ...     ...
# 5789              0.000000     red
# 5790              0.000000     red
# 5791              0.000000     red
# 5792              0.000000     red
# 5793              0.000000     red
#
# [5794 rows x 146 columns]

# %%
data = cumulative_df.drop(columns=["lev1", "winner", \
                                   "red_name", "blue_name"
                                  ])
number = LabelEncoder()
# data['red_name'] = number.fit_transform(data['red_name'].astype('str'))
# data['blue_name'] = number.fit_transform(data['blue_name'].astype('str'))
data['red_stance'] = number.fit_transform(data['red_stance'].astype('str'))
data['blue_stance'] = number.fit_transform(data['blue_stance'].astype('str'))
X = data
y = winners

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=200, activation='relu', input_dim=142)) 
model.add(Dense(units=200, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               28600
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               40200
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 69,202
# Trainable params: 69,202
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=0
)

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1449/1449 - 0s - loss: 2.3763 - accuracy: 0.6266
# Normal Neural Network - Loss: 2.376297614753781, Accuracy: 0.6266390681266785

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
d = {'prediction' : prediction_labels, 
     'actual' : y_test}

# %%
predictions_df = pd.DataFrame(data=d)
predictions_df.sample(30)
# Out:
#      prediction actual
# 1784        red    red
# 1655       blue   blue
# 4009        red    red
# 3279        red    red
# 579        blue    red
# 3074        red    red
# 5131       blue    red
# 5550        red    red
# 67          red   blue
# 1501       blue    red
# 3803       blue    red
# 3892        red    red
# 4090        red    red
# 2345        red   blue
# 3875       blue    red
# 4272        red    red
# 383         red    red
# 2031       blue    red
# 3313        red   blue
# 4870       blue    red
# 2820        red   blue
# 1683        red    red
# 250        blue   blue
# 5132        red    red
# 1321        red    red
# 4885        red    red
# 5101        red    red
# 4599        red    red
# 3635        red    red
# 3746        red   blue
