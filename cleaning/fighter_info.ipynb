# %%
import pandas as pd
pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
# Load in scraped fighter data
career_stats = pd.read_csv("../data/career_fighter_stats.csv")
career_stats = career_stats.drop(columns="Unnamed: 0")
career_stats
# Out:
#                  name      ufc_record                  nickname   height  \
# 0             Xie Bin           8-2-0                       NaN   5' 10"
# 1     Brandon Jenkins          15-8-0  THE HUMAN HIGHLIGHT REEL    6' 0"
# 2       Olivier Murad           4-0-0            WARRIOR OF GOD       --
# 3     Cameron VanCamp   15-5-1 (1 NC)                       NaN    6' 2"
# 4          Jose Alday          14-6-1                   POCHITO    5' 7"
# ...               ...             ...                       ...      ...
# 3718    Dave Zitanick    5-7-0 (1 NC)                       NaN       --
# 3719      Alex Zuniga           6-3-0                       NaN       --
# 3720    George Zuniga           3-1-0                       NaN    5' 9"
# 3721     Allan Zuniga          13-1-0                     TIGRE    5' 7"
# 3722   Virgil Zwicker          15-6-1                    REZDOG    6' 2"
#
#      reach weight     stance            DOB  SLpM  SApM  Str_Acc_pct  \
# 0       --    135        NaN   Feb 28, 1998  0.00  0.00          0.0
# 1      71"    155     Switch   Sep 30, 1991  2.81  5.90         39.0
# 2       --    145        NaN   Dec 21, 1993  0.00  0.00          0.0
# 3       --    155     Switch   Apr 27, 1993  0.00  0.00          0.0
# 4      68"    135   Orthodox   Sep 14, 1991  3.13  3.13         44.0
# ...    ...    ...        ...            ...   ...   ...          ...
# 3718    --    170        NaN   Mar 05, 1980  0.00  0.00          0.0
# 3719    --    145        NaN             --  0.00  0.00          0.0
# 3720    --    185        NaN             --  7.64  5.45         38.0
# 3721   70"    155   Orthodox   Apr 04, 1992  3.93  1.80         52.0
# 3722   74"    205        NaN   Jun 26, 1982  3.34  4.87         48.0
#
#       Str_Def_pct  TD_Avg  TD_Acc_pct  TD_Def_pct  Sub_Avg
# 0             0.0    0.00         0.0         0.0      0.0
# 1            35.0    0.00         0.0        25.0      0.0
# 2             0.0    0.00         0.0         0.0      0.0
# 3             0.0    0.00         0.0         0.0      0.0
# 4            58.0    0.00         0.0        57.0      0.0
# ...           ...     ...         ...         ...      ...
# 3718          0.0    0.00         0.0         0.0      0.0
# 3719          0.0    0.00         0.0         0.0      0.0
# 3720         37.0    0.00         0.0       100.0      0.0
# 3721         61.0    0.00         0.0        57.0      1.0
# 3722         39.0    1.31        30.0        50.0      0.0
#
# [3723 rows x 16 columns]

# %%
fighter_info = career_stats[["name", "DOB", "ufc_record", "height", "weight", "reach", "stance", "nickname"]]
fighter_info
# Out:
#                  name            DOB      ufc_record   height weight reach  \
# 0             Xie Bin   Feb 28, 1998           8-2-0   5' 10"    135    --
# 1     Brandon Jenkins   Sep 30, 1991          15-8-0    6' 0"    155   71"
# 2       Olivier Murad   Dec 21, 1993           4-0-0       --    145    --
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    6' 2"    155    --
# 4          Jose Alday   Sep 14, 1991          14-6-1    5' 7"    135   68"
# ...               ...            ...             ...      ...    ...   ...
# 3718    Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)       --    170    --
# 3719      Alex Zuniga             --           6-3-0       --    145    --
# 3720    George Zuniga             --           3-1-0    5' 9"    185    --
# 3721     Allan Zuniga   Apr 04, 1992          13-1-0    5' 7"    155   70"
# 3722   Virgil Zwicker   Jun 26, 1982          15-6-1    6' 2"    205   74"
#
#          stance                  nickname
# 0           NaN                       NaN
# 1        Switch  THE HUMAN HIGHLIGHT REEL
# 2           NaN            WARRIOR OF GOD
# 3        Switch                       NaN
# 4      Orthodox                   POCHITO
# ...         ...                       ...
# 3718        NaN                       NaN
# 3719        NaN                       NaN
# 3720        NaN                       NaN
# 3721   Orthodox                     TIGRE
# 3722        NaN                    REZDOG
#
# [3723 rows x 8 columns]

# %%
no_height = fighter_info[fighter_info["height"].str.contains("-")]
no_height
# Out:
#                     name            DOB     ufc_record height weight reach  \
# 2          Olivier Murad   Dec 21, 1993          4-0-0     --    145    --
# 26         Zhang Minyang             --          0-0-0     --     --    --
# 27             Tom Aaron   Jul 13, 1978          5-3-0     --    155    --
# 62           Brett Albee             --          3-2-0     --    225    --
# 67    Israel Albuquerque             --          0-3-0     --    185    --
# ...                  ...            ...            ...    ...    ...   ...
# 3681       Artenus Young   Jul 16, 1980        10-12-0     --    205    --
# 3694         Joao Zaiden   Mar 16, 1993         10-3-0     --    205    --
# 3713       Mike Zichelle             --          8-4-0     --    205    --
# 3718       Dave Zitanick   Mar 05, 1980   5-7-0 (1 NC)     --    170    --
# 3719         Alex Zuniga             --          6-3-0     --    145    --
#
#          stance        nickname
# 2           NaN  WARRIOR OF GOD
# 26          NaN             NaN
# 27          NaN             NaN
# 62          NaN             NaN
# 67     Orthodox             NaN
# ...         ...             ...
# 3681        NaN             NaN
# 3694        NaN             NaN
# 3713        NaN             NaN
# 3718        NaN             NaN
# 3719        NaN             NaN
#
# [275 rows x 8 columns]

# %%
# Removing fighters that have no height listed
fighter_info = fighter_info[~fighter_info["height"].str.contains("-")]
fighter_info
# Out:
#                  name            DOB      ufc_record   height weight reach  \
# 0             Xie Bin   Feb 28, 1998           8-2-0   5' 10"    135    --
# 1     Brandon Jenkins   Sep 30, 1991          15-8-0    6' 0"    155   71"
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    6' 2"    155    --
# 4          Jose Alday   Sep 14, 1991          14-6-1    5' 7"    135   68"
# 5        Tresean Gore   Jun 21, 1994           3-0-0    6' 0"    185    --
# ...               ...            ...             ...      ...    ...   ...
# 3716      Cat Zingano   Jul 01, 1982          10-4-0    5' 6"    145   68"
# 3717    Igor Zinoviev             --           4-1-2    6' 1"    199    --
# 3720    George Zuniga             --           3-1-0    5' 9"    185    --
# 3721     Allan Zuniga   Apr 04, 1992          13-1-0    5' 7"    155   70"
# 3722   Virgil Zwicker   Jun 26, 1982          15-6-1    6' 2"    205   74"
#
#          stance                  nickname
# 0           NaN                       NaN
# 1        Switch  THE HUMAN HIGHLIGHT REEL
# 3        Switch                       NaN
# 4      Orthodox                   POCHITO
# 5           NaN               MR. VICIOUS
# ...         ...                       ...
# 3716   Southpaw                     ALPHA
# 3717   Orthodox                   HOUDINI
# 3720        NaN                       NaN
# 3721   Orthodox                     TIGRE
# 3722        NaN                    REZDOG
#
# [3448 rows x 8 columns]

# %%
no_height["height"] = "8'5"
no_height
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                     name            DOB     ufc_record height weight reach  \
# 2          Olivier Murad   Dec 21, 1993          4-0-0    8'5    145    --
# 26         Zhang Minyang             --          0-0-0    8'5     --    --
# 27             Tom Aaron   Jul 13, 1978          5-3-0    8'5    155    --
# 62           Brett Albee             --          3-2-0    8'5    225    --
# 67    Israel Albuquerque             --          0-3-0    8'5    185    --
# ...                  ...            ...            ...    ...    ...   ...
# 3681       Artenus Young   Jul 16, 1980        10-12-0    8'5    205    --
# 3694         Joao Zaiden   Mar 16, 1993         10-3-0    8'5    205    --
# 3713       Mike Zichelle             --          8-4-0    8'5    205    --
# 3718       Dave Zitanick   Mar 05, 1980   5-7-0 (1 NC)    8'5    170    --
# 3719         Alex Zuniga             --          6-3-0    8'5    145    --
#
#          stance        nickname
# 2           NaN  WARRIOR OF GOD
# 26          NaN             NaN
# 27          NaN             NaN
# 62          NaN             NaN
# 67     Orthodox             NaN
# ...         ...             ...
# 3681        NaN             NaN
# 3694        NaN             NaN
# 3713        NaN             NaN
# 3718        NaN             NaN
# 3719        NaN             NaN
#
# [275 rows x 8 columns]

# %%
# And then putting the dataframes back together with aproximated reach for fighters with none listed
height_frames = [fighter_info, no_height]
fighter_info = pd.concat(height_frames)
fighter_info
# Out:
#                  name            DOB      ufc_record   height weight reach  \
# 0             Xie Bin   Feb 28, 1998           8-2-0   5' 10"    135    --
# 1     Brandon Jenkins   Sep 30, 1991          15-8-0    6' 0"    155   71"
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    6' 2"    155    --
# 4          Jose Alday   Sep 14, 1991          14-6-1    5' 7"    135   68"
# 5        Tresean Gore   Jun 21, 1994           3-0-0    6' 0"    185    --
# ...               ...            ...             ...      ...    ...   ...
# 3681    Artenus Young   Jul 16, 1980         10-12-0      8'5    205    --
# 3694      Joao Zaiden   Mar 16, 1993          10-3-0      8'5    205    --
# 3713    Mike Zichelle             --           8-4-0      8'5    205    --
# 3718    Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)      8'5    170    --
# 3719      Alex Zuniga             --           6-3-0      8'5    145    --
#
#          stance                  nickname
# 0           NaN                       NaN
# 1        Switch  THE HUMAN HIGHLIGHT REEL
# 3        Switch                       NaN
# 4      Orthodox                   POCHITO
# 5           NaN               MR. VICIOUS
# ...         ...                       ...
# 3681        NaN                       NaN
# 3694        NaN                       NaN
# 3713        NaN                       NaN
# 3718        NaN                       NaN
# 3719        NaN                       NaN
#
# [3723 rows x 8 columns]

# %%
fighter_info["height"].value_counts()
# Out:
#  6' 0"     416
#  5' 10"    364
#  5' 9"     364
#  5' 11"    340
#  6' 1"     290
#  5' 8"     285
# 8'5        275
#  5' 7"     264
#  6' 2"     244
#  5' 6"     215
#  6' 3"     201
#  5' 5"     117
#  6' 4"      89
#  5' 4"      84
#  5' 3"      50
#  6' 5"      38
#  5' 2"      20
#  6' 6"      20
#  5' 1"      13
#  6' 7"      12
#  6' 8"       9
#  5' 0"       4
#  6' 10"      3
#  6' 11"      3
#  6' 9"       1
#  7' 5"       1
#  7' 2"       1
# Name: height, dtype: int64

# %%
# Splitting feet and inches into seperate columns
fighter_info[["height_feet", "height_inches"]] = fighter_info.height.str.split("'", expand=True)
fighter_info
# Out:
#                  name            DOB      ufc_record   height weight reach  \
# 0             Xie Bin   Feb 28, 1998           8-2-0   5' 10"    135    --
# 1     Brandon Jenkins   Sep 30, 1991          15-8-0    6' 0"    155   71"
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    6' 2"    155    --
# 4          Jose Alday   Sep 14, 1991          14-6-1    5' 7"    135   68"
# 5        Tresean Gore   Jun 21, 1994           3-0-0    6' 0"    185    --
# ...               ...            ...             ...      ...    ...   ...
# 3681    Artenus Young   Jul 16, 1980         10-12-0      8'5    205    --
# 3694      Joao Zaiden   Mar 16, 1993          10-3-0      8'5    205    --
# 3713    Mike Zichelle             --           8-4-0      8'5    205    --
# 3718    Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)      8'5    170    --
# 3719      Alex Zuniga             --           6-3-0      8'5    145    --
#
#          stance                  nickname height_feet height_inches
# 0           NaN                       NaN           5           10"
# 1        Switch  THE HUMAN HIGHLIGHT REEL           6            0"
# 3        Switch                       NaN           6            2"
# 4      Orthodox                   POCHITO           5            7"
# 5           NaN               MR. VICIOUS           6            0"
# ...         ...                       ...         ...           ...
# 3681        NaN                       NaN           8             5
# 3694        NaN                       NaN           8             5
# 3713        NaN                       NaN           8             5
# 3718        NaN                       NaN           8             5
# 3719        NaN                       NaN           8             5
#
# [3723 rows x 10 columns]

# %%
# Stripping " from inches and converting height to int
fighter_info["height_inches"] = fighter_info["height_inches"].str.strip('"')
fighter_info["height_feet"] = fighter_info["height_feet"].astype(int)
fighter_info["height_inches"] = fighter_info["height_inches"].astype(int)
fighter_info
# Out:
#                  name            DOB      ufc_record   height weight reach  \
# 0             Xie Bin   Feb 28, 1998           8-2-0   5' 10"    135    --
# 1     Brandon Jenkins   Sep 30, 1991          15-8-0    6' 0"    155   71"
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    6' 2"    155    --
# 4          Jose Alday   Sep 14, 1991          14-6-1    5' 7"    135   68"
# 5        Tresean Gore   Jun 21, 1994           3-0-0    6' 0"    185    --
# ...               ...            ...             ...      ...    ...   ...
# 3681    Artenus Young   Jul 16, 1980         10-12-0      8'5    205    --
# 3694      Joao Zaiden   Mar 16, 1993          10-3-0      8'5    205    --
# 3713    Mike Zichelle             --           8-4-0      8'5    205    --
# 3718    Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)      8'5    170    --
# 3719      Alex Zuniga             --           6-3-0      8'5    145    --
#
#          stance                  nickname  height_feet  height_inches
# 0           NaN                       NaN            5             10
# 1        Switch  THE HUMAN HIGHLIGHT REEL            6              0
# 3        Switch                       NaN            6              2
# 4      Orthodox                   POCHITO            5              7
# 5           NaN               MR. VICIOUS            6              0
# ...         ...                       ...          ...            ...
# 3681        NaN                       NaN            8              5
# 3694        NaN                       NaN            8              5
# 3713        NaN                       NaN            8              5
# 3718        NaN                       NaN            8              5
# 3719        NaN                       NaN            8              5
#
# [3723 rows x 10 columns]

# %%
# Calculating total height from feet and inches columns
fighter_info["heightIN"] = (fighter_info["height_feet"] * 12) + fighter_info["height_inches"]
fighter_info
# Out:
#                  name            DOB      ufc_record   height weight reach  \
# 0             Xie Bin   Feb 28, 1998           8-2-0   5' 10"    135    --
# 1     Brandon Jenkins   Sep 30, 1991          15-8-0    6' 0"    155   71"
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    6' 2"    155    --
# 4          Jose Alday   Sep 14, 1991          14-6-1    5' 7"    135   68"
# 5        Tresean Gore   Jun 21, 1994           3-0-0    6' 0"    185    --
# ...               ...            ...             ...      ...    ...   ...
# 3681    Artenus Young   Jul 16, 1980         10-12-0      8'5    205    --
# 3694      Joao Zaiden   Mar 16, 1993          10-3-0      8'5    205    --
# 3713    Mike Zichelle             --           8-4-0      8'5    205    --
# 3718    Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)      8'5    170    --
# 3719      Alex Zuniga             --           6-3-0      8'5    145    --
#
#          stance                  nickname  height_feet  height_inches  \
# 0           NaN                       NaN            5             10
# 1        Switch  THE HUMAN HIGHLIGHT REEL            6              0
# 3        Switch                       NaN            6              2
# 4      Orthodox                   POCHITO            5              7
# 5           NaN               MR. VICIOUS            6              0
# ...         ...                       ...          ...            ...
# 3681        NaN                       NaN            8              5
# 3694        NaN                       NaN            8              5
# 3713        NaN                       NaN            8              5
# 3718        NaN                       NaN            8              5
# 3719        NaN                       NaN            8              5
#
#       heightIN
# 0           70
# 1           72
# 3           74
# 4           67
# 5           72
# ...        ...
# 3681       101
# 3694       101
# 3713       101
# 3718       101
# 3719       101
#
# [3723 rows x 11 columns]

# %%
# dropping old height columns
fighter_info = fighter_info.drop(columns=["height", "height_feet", "height_inches"])
fighter_info
# Out:
#                  name            DOB      ufc_record weight reach     stance  \
# 0             Xie Bin   Feb 28, 1998           8-2-0    135    --        NaN
# 1     Brandon Jenkins   Sep 30, 1991          15-8-0    155   71"     Switch
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    155    --     Switch
# 4          Jose Alday   Sep 14, 1991          14-6-1    135   68"   Orthodox
# 5        Tresean Gore   Jun 21, 1994           3-0-0    185    --        NaN
# ...               ...            ...             ...    ...   ...        ...
# 3681    Artenus Young   Jul 16, 1980         10-12-0    205    --        NaN
# 3694      Joao Zaiden   Mar 16, 1993          10-3-0    205    --        NaN
# 3713    Mike Zichelle             --           8-4-0    205    --        NaN
# 3718    Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)    170    --        NaN
# 3719      Alex Zuniga             --           6-3-0    145    --        NaN
#
#                       nickname  heightIN
# 0                          NaN        70
# 1     THE HUMAN HIGHLIGHT REEL        72
# 3                          NaN        74
# 4                      POCHITO        67
# 5                  MR. VICIOUS        72
# ...                        ...       ...
# 3681                       NaN       101
# 3694                       NaN       101
# 3713                       NaN       101
# 3718                       NaN       101
# 3719                       NaN       101
#
# [3723 rows x 8 columns]

# %%
# Stripping " from reach
fighter_info["reachIN"] = fighter_info["reach"]
fighter_info = fighter_info.drop(columns="reach")
fighter_info["reachIN"] = fighter_info["reachIN"].str.strip('"')
fighter_info
# Out:
#                  name            DOB      ufc_record weight     stance  \
# 0             Xie Bin   Feb 28, 1998           8-2-0    135        NaN
# 1     Brandon Jenkins   Sep 30, 1991          15-8-0    155     Switch
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    155     Switch
# 4          Jose Alday   Sep 14, 1991          14-6-1    135   Orthodox
# 5        Tresean Gore   Jun 21, 1994           3-0-0    185        NaN
# ...               ...            ...             ...    ...        ...
# 3681    Artenus Young   Jul 16, 1980         10-12-0    205        NaN
# 3694      Joao Zaiden   Mar 16, 1993          10-3-0    205        NaN
# 3713    Mike Zichelle             --           8-4-0    205        NaN
# 3718    Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)    170        NaN
# 3719      Alex Zuniga             --           6-3-0    145        NaN
#
#                       nickname  heightIN reachIN
# 0                          NaN        70      --
# 1     THE HUMAN HIGHLIGHT REEL        72      71
# 3                          NaN        74      --
# 4                      POCHITO        67      68
# 5                  MR. VICIOUS        72      --
# ...                        ...       ...     ...
# 3681                       NaN       101      --
# 3694                       NaN       101      --
# 3713                       NaN       101      --
# 3718                       NaN       101      --
# 3719                       NaN       101      --
#
# [3723 rows x 8 columns]

# %%
# splitting fighters into two seperate dataframes based on if they have reach listed...
no_reach = fighter_info[fighter_info["reachIN"].str.contains("-")]
no_reach
# Out:
#                  name            DOB      ufc_record weight   stance  \
# 0             Xie Bin   Feb 28, 1998           8-2-0    135      NaN
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    155   Switch
# 5        Tresean Gore   Jun 21, 1994           3-0-0    185      NaN
# 7        Dylan Potter             --          10-5-0    205      NaN
# 8        Reyes Cortez   Jul 31, 1992           5-1-0    135      NaN
# ...               ...            ...             ...    ...      ...
# 3681    Artenus Young   Jul 16, 1980         10-12-0    205      NaN
# 3694      Joao Zaiden   Mar 16, 1993          10-3-0    205      NaN
# 3713    Mike Zichelle             --           8-4-0    205      NaN
# 3718    Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)    170      NaN
# 3719      Alex Zuniga             --           6-3-0    145      NaN
#
#          nickname  heightIN reachIN
# 0             NaN        70      --
# 3             NaN        74      --
# 5     MR. VICIOUS        72      --
# 7       BIG POPPA        74      --
# 8          JUNIOR        67      --
# ...           ...       ...     ...
# 3681          NaN       101      --
# 3694          NaN       101      --
# 3713          NaN       101      --
# 3718          NaN       101      --
# 3719          NaN       101      --
#
# [2009 rows x 8 columns]

# %%
# ... as a majorit of fighters have no reach listed, it was necessary to aproximate... 
reach = fighter_info[~fighter_info["reachIN"].str.contains("-")]
reach
# Out:
#                        name            DOB ufc_record weight     stance  \
# 1           Brandon Jenkins   Sep 30, 1991     15-8-0    155     Switch
# 4                Jose Alday   Sep 14, 1991     14-6-1    135   Orthodox
# 6               Logan Urban   Apr 22, 1994      5-2-0    170   Orthodox
# 11         Micheal Gillmore   Mar 28, 1987      6-3-0    185   Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995      9-2-0    135   Orthodox
# ...                     ...            ...        ...    ...        ...
# 3712             Fares Ziam   Mar 21, 1997     12-3-0    155   Orthodox
# 3716            Cat Zingano   Jul 01, 1982     10-4-0    145   Southpaw
# 3721           Allan Zuniga   Apr 04, 1992     13-1-0    155   Orthodox
# 3722         Virgil Zwicker   Jun 26, 1982     15-6-1    205        NaN
# 980        Edward Faaloloto   Jul 15, 1984      2-5-0    155        NaN
#
#                       nickname  heightIN reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72      71
# 4                      POCHITO        67      68
# 6                         HULK        72      72
# 11               THE GENTLEMAN        71      74
# 12                         NaN        68      69
# ...                        ...       ...     ...
# 3712              SMILE KILLER        73      75
# 3716                     ALPHA        66      68
# 3721                     TIGRE        67      70
# 3722                    REZDOG        74      74
# 980                        NaN       101      70
#
# [1714 rows x 8 columns]

# %%
# ... by using height as a proxy for reach  
no_reach["reachIN"] = no_reach["heightIN"]
no_reach
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                  name            DOB      ufc_record weight   stance  \
# 0             Xie Bin   Feb 28, 1998           8-2-0    135      NaN
# 3     Cameron VanCamp   Apr 27, 1993   15-5-1 (1 NC)    155   Switch
# 5        Tresean Gore   Jun 21, 1994           3-0-0    185      NaN
# 7        Dylan Potter             --          10-5-0    205      NaN
# 8        Reyes Cortez   Jul 31, 1992           5-1-0    135      NaN
# ...               ...            ...             ...    ...      ...
# 3681    Artenus Young   Jul 16, 1980         10-12-0    205      NaN
# 3694      Joao Zaiden   Mar 16, 1993          10-3-0    205      NaN
# 3713    Mike Zichelle             --           8-4-0    205      NaN
# 3718    Dave Zitanick   Mar 05, 1980    5-7-0 (1 NC)    170      NaN
# 3719      Alex Zuniga             --           6-3-0    145      NaN
#
#          nickname  heightIN  reachIN
# 0             NaN        70       70
# 3             NaN        74       74
# 5     MR. VICIOUS        72       72
# 7       BIG POPPA        74       74
# 8          JUNIOR        67       67
# ...           ...       ...      ...
# 3681          NaN       101      101
# 3694          NaN       101      101
# 3713          NaN       101      101
# 3718          NaN       101      101
# 3719          NaN       101      101
#
# [2009 rows x 8 columns]

# %%
# And then putting the dataframes back together with aproximated reach for fighters with none listed
reach_frames = [reach, no_reach]
fighter_df = pd.concat(reach_frames)
fighter_df
# Out:
#                        name            DOB     ufc_record weight     stance  \
# 1           Brandon Jenkins   Sep 30, 1991         15-8-0    155     Switch
# 4                Jose Alday   Sep 14, 1991         14-6-1    135   Orthodox
# 6               Logan Urban   Apr 22, 1994          5-2-0    170   Orthodox
# 11         Micheal Gillmore   Mar 28, 1987          6-3-0    185   Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995          9-2-0    135   Orthodox
# ...                     ...            ...            ...    ...        ...
# 3681          Artenus Young   Jul 16, 1980        10-12-0    205        NaN
# 3694            Joao Zaiden   Mar 16, 1993         10-3-0    205        NaN
# 3713          Mike Zichelle             --          8-4-0    205        NaN
# 3718          Dave Zitanick   Mar 05, 1980   5-7-0 (1 NC)    170        NaN
# 3719            Alex Zuniga             --          6-3-0    145        NaN
#
#                       nickname  heightIN reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72      71
# 4                      POCHITO        67      68
# 6                         HULK        72      72
# 11               THE GENTLEMAN        71      74
# 12                         NaN        68      69
# ...                        ...       ...     ...
# 3681                       NaN       101     101
# 3694                       NaN       101     101
# 3713                       NaN       101     101
# 3718                       NaN       101     101
# 3719                       NaN       101     101
#
# [3723 rows x 8 columns]

# %%
fighter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3723 entries, 1 to 3719
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3723 non-null   object
#  1   DOB         3723 non-null   object
#  2   ufc_record  3723 non-null   object
#  3   weight      3723 non-null   object
#  4   stance      2824 non-null   object
#  5   nickname    1977 non-null   object
#  6   heightIN    3723 non-null   int32
#  7   reachIN     3723 non-null   object
# dtypes: int32(1), object(7)
# memory usage: 247.2+ KB

# %%
# setting reach as int
fighter_df["reachIN"] = fighter_df["reachIN"].astype(int)
fighter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3723 entries, 1 to 3719
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3723 non-null   object
#  1   DOB         3723 non-null   object
#  2   ufc_record  3723 non-null   object
#  3   weight      3723 non-null   object
#  4   stance      2824 non-null   object
#  5   nickname    1977 non-null   object
#  6   heightIN    3723 non-null   int32
#  7   reachIN     3723 non-null   int32
# dtypes: int32(2), object(6)
# memory usage: 232.7+ KB

# %%
fighter_df["stance"].value_counts()
# Out:
#  Orthodox       2189
#  Southpaw        495
#  Switch          130
#  Open Stance       7
#  Sideways          3
# Name: stance, dtype: int64

# %%
fighter_df["stance"] = fighter_df["stance"].astype(str)
fighter_df["ufc_record"] = fighter_df["ufc_record"].astype(str)

# %%
fighter_df[fighter_df["stance"] == "nan"]
# Out:
#                  name            DOB     ufc_record weight stance  \
# 309   Khadzhi Bestaev   Jul 16, 1988         10-4-0    185    nan
# 403     Antwain Britt   May 09, 1978         11-6-0    205    nan
# 438        Julia Budd   Jul 04, 1983         10-2-0    145    nan
# 626    Marloes Coenen   Mar 31, 1981         23-8-0    145    nan
# 962       Juan Espino   Oct 09, 1980         11-2-0    255    nan
# ...               ...            ...            ...    ...    ...
# 3681    Artenus Young   Jul 16, 1980        10-12-0    205    nan
# 3694      Joao Zaiden   Mar 16, 1993         10-3-0    205    nan
# 3713    Mike Zichelle             --          8-4-0    205    nan
# 3718    Dave Zitanick   Mar 05, 1980   5-7-0 (1 NC)    170    nan
# 3719      Alex Zuniga             --          6-3-0    145    nan
#
#             nickname  heightIN  reachIN
# 309             BEST        78       76
# 403   THE JUGGERNAUT        73       77
# 438              NaN        67       67
# 626              NaN        69       67
# 962         EL GUAPO        75       80
# ...              ...       ...      ...
# 3681             NaN       101      101
# 3694             NaN       101      101
# 3713             NaN       101      101
# 3718             NaN       101      101
# 3719             NaN       101      101
#
# [899 rows x 8 columns]

# %%
# Seeing as the vast majority of fighters are orthadox, assume that nan values are orthadox...
fighter_df["stance"] = fighter_df["stance"].replace({"nan" : "Unknown"})
fighter_df["stance"] = fighter_df["stance"].replace({" Orthodox" : "Orthodox"})
fighter_df["stance"] = fighter_df["stance"].replace({" Southpaw" : "Southpaw"})
fighter_df["stance"] = fighter_df["stance"].replace({" Switch" : "Switch"})
fighter_df["stance"] = fighter_df["stance"].replace({" Open Stance" : "Switch"}) # With open as switch
fighter_df["stance"] = fighter_df["stance"].replace({" Sideways" : "Switch"}) # and same with sideways
fighter_df["stance"].value_counts()
# Out:
# Orthodox    2189
# Unknown      899
# Southpaw     495
# Switch       140
# Name: stance, dtype: int64

# %%
fighter_df["weight"].value_counts()
# Out:
# 170    569
# 155    545
# 185    465
# 145    405
# 135    376
#       ...
# 233      1
# 186      1
# 323      1
# 212      1
# 259      1
# Name: weight, Length: 113, dtype: int64

# %%
fighter_df["weight"].isna().sum()
# Out:
# 0

# %%
fighter_df
# Out:
#                        name            DOB     ufc_record weight    stance  \
# 1           Brandon Jenkins   Sep 30, 1991         15-8-0    155    Switch
# 4                Jose Alday   Sep 14, 1991         14-6-1    135  Orthodox
# 6               Logan Urban   Apr 22, 1994          5-2-0    170  Orthodox
# 11         Micheal Gillmore   Mar 28, 1987          6-3-0    185  Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995          9-2-0    135  Orthodox
# ...                     ...            ...            ...    ...       ...
# 3681          Artenus Young   Jul 16, 1980        10-12-0    205   Unknown
# 3694            Joao Zaiden   Mar 16, 1993         10-3-0    205   Unknown
# 3713          Mike Zichelle             --          8-4-0    205   Unknown
# 3718          Dave Zitanick   Mar 05, 1980   5-7-0 (1 NC)    170   Unknown
# 3719            Alex Zuniga             --          6-3-0    145   Unknown
#
#                       nickname  heightIN  reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72       71
# 4                      POCHITO        67       68
# 6                         HULK        72       72
# 11               THE GENTLEMAN        71       74
# 12                         NaN        68       69
# ...                        ...       ...      ...
# 3681                       NaN       101      101
# 3694                       NaN       101      101
# 3713                       NaN       101      101
# 3718                       NaN       101      101
# 3719                       NaN       101      101
#
# [3723 rows x 8 columns]

# %%
# fighters with no date of birth makes it impossible to calculate age at time of fight later on...
no_dob = fighter_df[fighter_df["DOB"].str.contains("-")]
no_dob
# Out:
#                       name  DOB ufc_record weight    stance    nickname  \
# 921             Per Eklund   --     14-5-1    155  Orthodox         NaN
# 1892          Jess Liaudin   --    20-11-0    170  Orthodox   THE JOKER
# 3548        Curt Warburton   --     13-6-0    155  Orthodox         NaN
# 7             Dylan Potter   --     10-5-0    205   Unknown   BIG POPPA
# 10    Jack Della Maddalena   --      9-2-0    170   Unknown         NaN
# ...                    ...  ...        ...    ...       ...         ...
# 3637        Hunter Worsham   --      7-3-0    185   Unknown  THE FUTURE
# 3642          Chris Wright   --      8-5-1     --   Unknown         NaN
# 3675              John Yoo   --      0-1-0    135   Unknown         NaN
# 3713         Mike Zichelle   --      8-4-0    205   Unknown         NaN
# 3719           Alex Zuniga   --      6-3-0    145   Unknown         NaN
#
#       heightIN  reachIN
# 921         70       72
# 1892        69       72
# 3548        72       73
# 7           74       74
# 10          71       71
# ...        ...      ...
# 3637       101      101
# 3642       101      101
# 3675       101      101
# 3713       101      101
# 3719       101      101
#
# [765 rows x 8 columns]

# %%
no_dob["DOB"] = "Jan 1, 1900"
no_dob
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                       name          DOB ufc_record weight    stance  \
# 921             Per Eklund  Jan 1, 1900     14-5-1    155  Orthodox
# 1892          Jess Liaudin  Jan 1, 1900    20-11-0    170  Orthodox
# 3548        Curt Warburton  Jan 1, 1900     13-6-0    155  Orthodox
# 7             Dylan Potter  Jan 1, 1900     10-5-0    205   Unknown
# 10    Jack Della Maddalena  Jan 1, 1900      9-2-0    170   Unknown
# ...                    ...          ...        ...    ...       ...
# 3637        Hunter Worsham  Jan 1, 1900      7-3-0    185   Unknown
# 3642          Chris Wright  Jan 1, 1900      8-5-1     --   Unknown
# 3675              John Yoo  Jan 1, 1900      0-1-0    135   Unknown
# 3713         Mike Zichelle  Jan 1, 1900      8-4-0    205   Unknown
# 3719           Alex Zuniga  Jan 1, 1900      6-3-0    145   Unknown
#
#         nickname  heightIN  reachIN
# 921          NaN        70       72
# 1892   THE JOKER        69       72
# 3548         NaN        72       73
# 7      BIG POPPA        74       74
# 10           NaN        71       71
# ...          ...       ...      ...
# 3637  THE FUTURE       101      101
# 3642         NaN       101      101
# 3675         NaN       101      101
# 3713         NaN       101      101
# 3719         NaN       101      101
#
# [765 rows x 8 columns]

# %%
# ... so fighters with no DOB are dropped
dob = fighter_df[~fighter_df["DOB"].str.contains("-")]

# %%
dob_frames = [dob, no_dob]
clean_fighter_df = pd.concat(dob_frames)
clean_fighter_df
# Out:
#                        name            DOB ufc_record weight    stance  \
# 1           Brandon Jenkins   Sep 30, 1991     15-8-0    155    Switch
# 4                Jose Alday   Sep 14, 1991     14-6-1    135  Orthodox
# 6               Logan Urban   Apr 22, 1994      5-2-0    170  Orthodox
# 11         Micheal Gillmore   Mar 28, 1987      6-3-0    185  Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995      9-2-0    135  Orthodox
# ...                     ...            ...        ...    ...       ...
# 3637         Hunter Worsham    Jan 1, 1900      7-3-0    185   Unknown
# 3642           Chris Wright    Jan 1, 1900      8-5-1     --   Unknown
# 3675               John Yoo    Jan 1, 1900      0-1-0    135   Unknown
# 3713          Mike Zichelle    Jan 1, 1900      8-4-0    205   Unknown
# 3719            Alex Zuniga    Jan 1, 1900      6-3-0    145   Unknown
#
#                       nickname  heightIN  reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72       71
# 4                      POCHITO        67       68
# 6                         HULK        72       72
# 11               THE GENTLEMAN        71       74
# 12                         NaN        68       69
# ...                        ...       ...      ...
# 3637                THE FUTURE       101      101
# 3642                       NaN       101      101
# 3675                       NaN       101      101
# 3713                       NaN       101      101
# 3719                       NaN       101      101
#
# [3723 rows x 8 columns]

# %%
# Saving the clean dataframe
clean_fighter_df.to_csv("../data/clean_fighter_info.csv")
clean_fighter_df
# Out:
#                        name            DOB ufc_record weight    stance  \
# 1           Brandon Jenkins   Sep 30, 1991     15-8-0    155    Switch
# 4                Jose Alday   Sep 14, 1991     14-6-1    135  Orthodox
# 6               Logan Urban   Apr 22, 1994      5-2-0    170  Orthodox
# 11         Micheal Gillmore   Mar 28, 1987      6-3-0    185  Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995      9-2-0    135  Orthodox
# ...                     ...            ...        ...    ...       ...
# 3637         Hunter Worsham    Jan 1, 1900      7-3-0    185   Unknown
# 3642           Chris Wright    Jan 1, 1900      8-5-1     --   Unknown
# 3675               John Yoo    Jan 1, 1900      0-1-0    135   Unknown
# 3713          Mike Zichelle    Jan 1, 1900      8-4-0    205   Unknown
# 3719            Alex Zuniga    Jan 1, 1900      6-3-0    145   Unknown
#
#                       nickname  heightIN  reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72       71
# 4                      POCHITO        67       68
# 6                         HULK        72       72
# 11               THE GENTLEMAN        71       74
# 12                         NaN        68       69
# ...                        ...       ...      ...
# 3637                THE FUTURE       101      101
# 3642                       NaN       101      101
# 3675                       NaN       101      101
# 3713                       NaN       101      101
# 3719                       NaN       101      101
#
# [3723 rows x 8 columns]

# %%
clean_fighter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3723 entries, 1 to 3719
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        3723 non-null   object
#  1   DOB         3723 non-null   object
#  2   ufc_record  3723 non-null   object
#  3   weight      3723 non-null   object
#  4   stance      3723 non-null   object
#  5   nickname    1977 non-null   object
#  6   heightIN    3723 non-null   int32
#  7   reachIN     3723 non-null   int32
# dtypes: int32(2), object(6)
# memory usage: 232.7+ KB

# %%
clean_fighter_df["name"].value_counts()
# Out:
# Michael McDonald      2
# Bruno Silva           2
# Tony Johnson          2
# Mike Davis            2
# Joey Gomez            2
#                      ..
# Miguel Torres         1
# Ashlee Evans-Smith    1
# Brian Foster          1
# Christian Uflacker    1
# Stephen Banaszak      1
# Name: name, Length: 3718, dtype: int64

# %%
name_count_df = pd.DataFrame(clean_fighter_df["name"].value_counts())
name_count_df
# Out:
#                     name
# Michael McDonald       2
# Bruno Silva            2
# Tony Johnson           2
# Mike Davis             2
# Joey Gomez             2
# ...                  ...
# Miguel Torres          1
# Ashlee Evans-Smith     1
# Brian Foster           1
# Christian Uflacker     1
# Stephen Banaszak       1
#
# [3718 rows x 1 columns]

# %%
multi_name = name_count_df[name_count_df["name"] > 1]
multi_name
# Out:
#                   name
# Michael McDonald     2
# Bruno Silva          2
# Tony Johnson         2
# Mike Davis           2
# Joey Gomez           2

# %%
clean_fighter_df[clean_fighter_df["name"] == "Mike Davis"]
# Out:
#            name            DOB ufc_record weight    stance   nickname  \
# 764  Mike Davis   Oct 07, 1992      9-2-0    145  Orthodox  BEAST BOY
# 759  Mike Davis    Jan 1, 1900      2-0-0     --   Unknown        NaN
#
#      heightIN  reachIN
# 764        72       72
# 759       101      101

# %%
clean_fighter_df = clean_fighter_df[clean_fighter_df["name"] != "Mike Davis"]
clean_fighter_df
# Out:
#                        name            DOB ufc_record weight    stance  \
# 1           Brandon Jenkins   Sep 30, 1991     15-8-0    155    Switch
# 4                Jose Alday   Sep 14, 1991     14-6-1    135  Orthodox
# 6               Logan Urban   Apr 22, 1994      5-2-0    170  Orthodox
# 11         Micheal Gillmore   Mar 28, 1987      6-3-0    185  Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995      9-2-0    135  Orthodox
# ...                     ...            ...        ...    ...       ...
# 3637         Hunter Worsham    Jan 1, 1900      7-3-0    185   Unknown
# 3642           Chris Wright    Jan 1, 1900      8-5-1     --   Unknown
# 3675               John Yoo    Jan 1, 1900      0-1-0    135   Unknown
# 3713          Mike Zichelle    Jan 1, 1900      8-4-0    205   Unknown
# 3719            Alex Zuniga    Jan 1, 1900      6-3-0    145   Unknown
#
#                       nickname  heightIN  reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72       71
# 4                      POCHITO        67       68
# 6                         HULK        72       72
# 11               THE GENTLEMAN        71       74
# 12                         NaN        68       69
# ...                        ...       ...      ...
# 3637                THE FUTURE       101      101
# 3642                       NaN       101      101
# 3675                       NaN       101      101
# 3713                       NaN       101      101
# 3719                       NaN       101      101
#
# [3721 rows x 8 columns]

# %%
clean_fighter_df[clean_fighter_df["name"] == "Tony Johnson"]
# Out:
#               name            DOB ufc_record weight    stance nickname  \
# 1591  Tony Johnson   May 02, 1983      7-2-0    205  Orthodox      NaN
# 1599  Tony Johnson    Jan 1, 1900     11-3-0    265   Unknown      NaN
#
#       heightIN  reachIN
# 1591        74       76
# 1599        73       73

# %%
clean_fighter_df = clean_fighter_df[clean_fighter_df["name"] != "Tony Johnson"]
clean_fighter_df
# Out:
#                        name            DOB ufc_record weight    stance  \
# 1           Brandon Jenkins   Sep 30, 1991     15-8-0    155    Switch
# 4                Jose Alday   Sep 14, 1991     14-6-1    135  Orthodox
# 6               Logan Urban   Apr 22, 1994      5-2-0    170  Orthodox
# 11         Micheal Gillmore   Mar 28, 1987      6-3-0    185  Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995      9-2-0    135  Orthodox
# ...                     ...            ...        ...    ...       ...
# 3637         Hunter Worsham    Jan 1, 1900      7-3-0    185   Unknown
# 3642           Chris Wright    Jan 1, 1900      8-5-1     --   Unknown
# 3675               John Yoo    Jan 1, 1900      0-1-0    135   Unknown
# 3713          Mike Zichelle    Jan 1, 1900      8-4-0    205   Unknown
# 3719            Alex Zuniga    Jan 1, 1900      6-3-0    145   Unknown
#
#                       nickname  heightIN  reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72       71
# 4                      POCHITO        67       68
# 6                         HULK        72       72
# 11               THE GENTLEMAN        71       74
# 12                         NaN        68       69
# ...                        ...       ...      ...
# 3637                THE FUTURE       101      101
# 3642                       NaN       101      101
# 3675                       NaN       101      101
# 3713                       NaN       101      101
# 3719                       NaN       101      101
#
# [3719 rows x 8 columns]

# %%
clean_fighter_df[clean_fighter_df["name"] == "Bruno Silva"]
# Out:
#              name            DOB      ufc_record weight    stance  nickname  \
# 3104  Bruno Silva   Mar 16, 1990   12-5-2 (1 NC)    125  Orthodox   BULLDOG
# 3105  Bruno Silva   Jul 13, 1989          20-6-0    185  Orthodox  BLINDADO
#
#       heightIN  reachIN
# 3104        64       65
# 3105        72       74

# %%
clean_fighter_df = clean_fighter_df[clean_fighter_df["name"] != "Bruno Silva"]
clean_fighter_df
# Out:
#                        name            DOB ufc_record weight    stance  \
# 1           Brandon Jenkins   Sep 30, 1991     15-8-0    155    Switch
# 4                Jose Alday   Sep 14, 1991     14-6-1    135  Orthodox
# 6               Logan Urban   Apr 22, 1994      5-2-0    170  Orthodox
# 11         Micheal Gillmore   Mar 28, 1987      6-3-0    185  Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995      9-2-0    135  Orthodox
# ...                     ...            ...        ...    ...       ...
# 3637         Hunter Worsham    Jan 1, 1900      7-3-0    185   Unknown
# 3642           Chris Wright    Jan 1, 1900      8-5-1     --   Unknown
# 3675               John Yoo    Jan 1, 1900      0-1-0    135   Unknown
# 3713          Mike Zichelle    Jan 1, 1900      8-4-0    205   Unknown
# 3719            Alex Zuniga    Jan 1, 1900      6-3-0    145   Unknown
#
#                       nickname  heightIN  reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72       71
# 4                      POCHITO        67       68
# 6                         HULK        72       72
# 11               THE GENTLEMAN        71       74
# 12                         NaN        68       69
# ...                        ...       ...      ...
# 3637                THE FUTURE       101      101
# 3642                       NaN       101      101
# 3675                       NaN       101      101
# 3713                       NaN       101      101
# 3719                       NaN       101      101
#
# [3717 rows x 8 columns]

# %%
clean_fighter_df[clean_fighter_df["name"] == "Michael McDonald"]
# Out:
#                   name            DOB ufc_record weight    stance  \
# 2109  Michael McDonald   Jan 15, 1991     17-4-0    135  Orthodox
# 2107  Michael McDonald   Feb 06, 1965      1-1-0    205  Orthodox
#
#               nickname  heightIN  reachIN
# 2109            MAYDAY        69       70
# 2107  THE BLACK SNIPER        71       71

# %%
clean_fighter_df = clean_fighter_df[clean_fighter_df["name"] != "Michael McDonald"]
clean_fighter_df
# Out:
#                        name            DOB ufc_record weight    stance  \
# 1           Brandon Jenkins   Sep 30, 1991     15-8-0    155    Switch
# 4                Jose Alday   Sep 14, 1991     14-6-1    135  Orthodox
# 6               Logan Urban   Apr 22, 1994      5-2-0    170  Orthodox
# 11         Micheal Gillmore   Mar 28, 1987      6-3-0    185  Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995      9-2-0    135  Orthodox
# ...                     ...            ...        ...    ...       ...
# 3637         Hunter Worsham    Jan 1, 1900      7-3-0    185   Unknown
# 3642           Chris Wright    Jan 1, 1900      8-5-1     --   Unknown
# 3675               John Yoo    Jan 1, 1900      0-1-0    135   Unknown
# 3713          Mike Zichelle    Jan 1, 1900      8-4-0    205   Unknown
# 3719            Alex Zuniga    Jan 1, 1900      6-3-0    145   Unknown
#
#                       nickname  heightIN  reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72       71
# 4                      POCHITO        67       68
# 6                         HULK        72       72
# 11               THE GENTLEMAN        71       74
# 12                         NaN        68       69
# ...                        ...       ...      ...
# 3637                THE FUTURE       101      101
# 3642                       NaN       101      101
# 3675                       NaN       101      101
# 3713                       NaN       101      101
# 3719                       NaN       101      101
#
# [3715 rows x 8 columns]

# %%
clean_fighter_df[clean_fighter_df["name"] == "Joey Gomez"]
# Out:
#             name            DOB ufc_record weight    stance nickname  \
# 1196  Joey Gomez   Jul 21, 1986      6-2-0    135  Orthodox  KO KING
# 1198  Joey Gomez   Aug 29, 1989      7-1-0    155  Orthodox      NaN
#
#       heightIN  reachIN
# 1196        70       73
# 1198        70       71

# %%
clean_fighter_df = clean_fighter_df[clean_fighter_df["name"] != "Joey Gomez"]
clean_fighter_df
# Out:
#                        name            DOB ufc_record weight    stance  \
# 1           Brandon Jenkins   Sep 30, 1991     15-8-0    155    Switch
# 4                Jose Alday   Sep 14, 1991     14-6-1    135  Orthodox
# 6               Logan Urban   Apr 22, 1994      5-2-0    170  Orthodox
# 11         Micheal Gillmore   Mar 28, 1987      6-3-0    185  Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995      9-2-0    135  Orthodox
# ...                     ...            ...        ...    ...       ...
# 3637         Hunter Worsham    Jan 1, 1900      7-3-0    185   Unknown
# 3642           Chris Wright    Jan 1, 1900      8-5-1     --   Unknown
# 3675               John Yoo    Jan 1, 1900      0-1-0    135   Unknown
# 3713          Mike Zichelle    Jan 1, 1900      8-4-0    205   Unknown
# 3719            Alex Zuniga    Jan 1, 1900      6-3-0    145   Unknown
#
#                       nickname  heightIN  reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72       71
# 4                      POCHITO        67       68
# 6                         HULK        72       72
# 11               THE GENTLEMAN        71       74
# 12                         NaN        68       69
# ...                        ...       ...      ...
# 3637                THE FUTURE       101      101
# 3642                       NaN       101      101
# 3675                       NaN       101      101
# 3713                       NaN       101      101
# 3719                       NaN       101      101
#
# [3713 rows x 8 columns]

# %%
# Saving the clean dataframe
clean_fighter_df.to_csv("../data/clean_fighter_info.csv")
clean_fighter_df
# Out:
#                        name            DOB ufc_record weight    stance  \
# 1           Brandon Jenkins   Sep 30, 1991     15-8-0    155    Switch
# 4                Jose Alday   Sep 14, 1991     14-6-1    135  Orthodox
# 6               Logan Urban   Apr 22, 1994      5-2-0    170  Orthodox
# 11         Micheal Gillmore   Mar 28, 1987      6-3-0    185  Orthodox
# 12    Saidyokub Kakhramonov   Nov 14, 1995      9-2-0    135  Orthodox
# ...                     ...            ...        ...    ...       ...
# 3637         Hunter Worsham    Jan 1, 1900      7-3-0    185   Unknown
# 3642           Chris Wright    Jan 1, 1900      8-5-1     --   Unknown
# 3675               John Yoo    Jan 1, 1900      0-1-0    135   Unknown
# 3713          Mike Zichelle    Jan 1, 1900      8-4-0    205   Unknown
# 3719            Alex Zuniga    Jan 1, 1900      6-3-0    145   Unknown
#
#                       nickname  heightIN  reachIN
# 1     THE HUMAN HIGHLIGHT REEL        72       71
# 4                      POCHITO        67       68
# 6                         HULK        72       72
# 11               THE GENTLEMAN        71       74
# 12                         NaN        68       69
# ...                        ...       ...      ...
# 3637                THE FUTURE       101      101
# 3642                       NaN       101      101
# 3675                       NaN       101      101
# 3713                       NaN       101      101
# 3719                       NaN       101      101
#
# [3713 rows x 8 columns]
