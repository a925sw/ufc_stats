# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import feature_extraction, model_selection, naive_bayes, pipeline, manifold, preprocessing, metrics
from tensorflow.keras import models, layers, preprocessing as kprocessing
from tensorflow.keras import backend as K
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
import pickle

# %%
big_df = pd.read_csv("../data/big_df.csv")
big_df
# Out:
#       lev1  blue_age  red_age  blue_heightIN  red_heightIN         blue_name  \
# 0        0      30.0     37.0             73            72   Sean Strickland
# 1        1      24.0     28.0             73            72   Sean Strickland
# 2        2      27.0     33.0             73            71   Sean Strickland
# 3        3      26.0     30.0             73            72   Sean Strickland
# 4        4      30.0     25.0             73            74   Sean Strickland
# ...    ...       ...      ...            ...           ...               ...
# 5799  5799      25.0     31.0             70            72      Rodrigo Ruas
# 5800  5800      30.0     36.0             68            69     Chris Brennan
# 5801  5801      24.0     33.0             72            70  Kenichi Yamamoto
# 5802  5802      32.0     31.0             62            68        Phil Johns
# 5803  5803      23.0     30.0             72            68      Daiju Takase
#
#                   red_name  blue_reach  red_reach blue_stance  ...  \
# 0               Uriah Hall          76         79    Orthodox  ...
# 1     Santiago Ponzinibbio          76         73    Orthodox  ...
# 2              Court McGee          76         75    Orthodox  ...
# 3             Kamaru Usman          76         76    Orthodox  ...
# 4            Brendan Allen          76         75    Orthodox  ...
# ...                    ...         ...        ...         ...  ...
# 5799         Tony Fryklund          70         72    Orthodox  ...
# 5800          Gil Castillo          68         69    Orthodox  ...
# 5801          Pat Miletich          72         70    Orthodox  ...
# 5802           Fabiano Iha          62         68    Southpaw  ...
# 5803           Fabiano Iha          72         68    Southpaw  ...
#
#      blue_stk_body_abs_per_min  blue_stk_leg_abs_per_min  \
# 0                     0.978814                  0.889831
# 1                     0.818414                  0.409207
# 2                     0.798155                  0.574672
# 3                     0.658506                  0.455889
# 4                     0.876289                  0.839470
# ...                        ...                       ...
# 5799                  0.000000                  0.000000
# 5800                  0.000000                  0.000000
# 5801                  0.000000                  0.000000
# 5802                  0.000000                  0.000000
# 5803                  0.000000                  0.000000
#
#       blue_stk_dist_abs_per_min  blue_stk_clch_abs_per_min  \
# 0                      3.851695                   0.158898
# 1                      2.404092                   0.051151
# 2                      2.660518                   0.223484
# 3                      2.596032                   0.189954
# 4                      3.475700                   0.176730
# ...                         ...                        ...
# 5799                   0.000000                   0.000000
# 5800                   0.000000                   0.000000
# 5801                   0.000000                   0.000000
# 5802                   0.000000                   0.000000
# 5803                   0.000000                   0.000000
#
#       blue_stk_gnd_abs_per_min  blue_reach_dif  blue_height_dif  winner  \
# 0                     0.368644              -3                1     tbd
# 1                     0.000000               3                1     red
# 2                     0.553388               1                2    blue
# 3                     0.164626               0                1     red
# 4                     0.427099               1               -1    blue
# ...                        ...             ...              ...     ...
# 5799                  0.000000              -2               -2     red
# 5800                  0.000000              -1               -1     red
# 5801                  0.000000               2                2     red
# 5802                  0.000000              -6               -6     red
# 5803                  0.000000               4                4     red
#
#             weight_class  title_fight
# 0     Men's Middleweight            0
# 1     Men's Welterweight            0
# 2     Men's Welterweight            0
# 3     Men's Welterweight            0
# 4            Catchweight            0
# ...                  ...          ...
# 5799  Men's Middleweight            0
# 5800  Men's Welterweight            0
# 5801  Men's Welterweight            1
# 5802  Men's Welterweight            0
# 5803  Men's Welterweight            0
#
# [5804 rows x 178 columns]

# %%
df = big_df[big_df["winner"] != "tbd"]
df
# Out:
#       lev1  blue_age  red_age  blue_heightIN  red_heightIN         blue_name  \
# 1        1      24.0     28.0             73            72   Sean Strickland
# 2        2      27.0     33.0             73            71   Sean Strickland
# 3        3      26.0     30.0             73            72   Sean Strickland
# 4        4      30.0     25.0             73            74   Sean Strickland
# 5        5      27.0     31.0             73            71   Sean Strickland
# ...    ...       ...      ...            ...           ...               ...
# 5799  5799      25.0     31.0             70            72      Rodrigo Ruas
# 5800  5800      30.0     36.0             68            69     Chris Brennan
# 5801  5801      24.0     33.0             72            70  Kenichi Yamamoto
# 5802  5802      32.0     31.0             62            68        Phil Johns
# 5803  5803      23.0     30.0             72            68      Daiju Takase
#
#                        red_name  blue_reach  red_reach blue_stance  ...  \
# 1          Santiago Ponzinibbio          76         73    Orthodox  ...
# 2                   Court McGee          76         75    Orthodox  ...
# 3                  Kamaru Usman          76         76    Orthodox  ...
# 4                 Brendan Allen          76         75    Orthodox  ...
# 5     Elizeu Zaleski dos Santos          76         73    Orthodox  ...
# ...                         ...         ...        ...         ...  ...
# 5799              Tony Fryklund          70         72    Orthodox  ...
# 5800               Gil Castillo          68         69    Orthodox  ...
# 5801               Pat Miletich          72         70    Orthodox  ...
# 5802                Fabiano Iha          62         68    Southpaw  ...
# 5803                Fabiano Iha          72         68    Southpaw  ...
#
#      blue_stk_body_abs_per_min  blue_stk_leg_abs_per_min  \
# 1                     0.818414                  0.409207
# 2                     0.798155                  0.574672
# 3                     0.658506                  0.455889
# 4                     0.876289                  0.839470
# 5                     0.825941                  0.752524
# ...                        ...                       ...
# 5799                  0.000000                  0.000000
# 5800                  0.000000                  0.000000
# 5801                  0.000000                  0.000000
# 5802                  0.000000                  0.000000
# 5803                  0.000000                  0.000000
#
#       blue_stk_dist_abs_per_min  blue_stk_clch_abs_per_min  \
# 1                      2.404092                   0.051151
# 2                      2.660518                   0.223484
# 3                      2.596032                   0.189954
# 4                      3.475700                   0.176730
# 5                      2.835730                   0.220251
# ...                         ...                        ...
# 5799                   0.000000                   0.000000
# 5800                   0.000000                   0.000000
# 5801                   0.000000                   0.000000
# 5802                   0.000000                   0.000000
# 5803                   0.000000                   0.000000
#
#       blue_stk_gnd_abs_per_min  blue_reach_dif  blue_height_dif  winner  \
# 1                     0.000000               3                1     red
# 2                     0.553388               1                2    blue
# 3                     0.164626               0                1     red
# 4                     0.427099               1               -1    blue
# 5                     0.477210               3                2     red
# ...                        ...             ...              ...     ...
# 5799                  0.000000              -2               -2     red
# 5800                  0.000000              -1               -1     red
# 5801                  0.000000               2                2     red
# 5802                  0.000000              -6               -6     red
# 5803                  0.000000               4                4     red
#
#             weight_class  title_fight
# 1     Men's Welterweight            0
# 2     Men's Welterweight            0
# 3     Men's Welterweight            0
# 4            Catchweight            0
# 5     Men's Welterweight            0
# ...                  ...          ...
# 5799  Men's Middleweight            0
# 5800  Men's Welterweight            0
# 5801  Men's Welterweight            1
# 5802  Men's Welterweight            0
# 5803  Men's Welterweight            0
#
# [5793 rows x 178 columns]

# %%
number = LabelEncoder()
# data['red_name'] = number.fit_transform(data['red_name'].astype('str'))
# data['blue_name'] = number.fit_transform(data['blue_name'].astype('str'))
df['red_stance'] = number.fit_transform(df['red_stance'].astype('str'))
df['blue_stance'] = number.fit_transform(df['blue_stance'].astype('str'))
df['weight_class'] = number.fit_transform(df['weight_class'].astype('str'))
df
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       lev1  blue_age  red_age  blue_heightIN  red_heightIN         blue_name  \
# 1        1      24.0     28.0             73            72   Sean Strickland
# 2        2      27.0     33.0             73            71   Sean Strickland
# 3        3      26.0     30.0             73            72   Sean Strickland
# 4        4      30.0     25.0             73            74   Sean Strickland
# 5        5      27.0     31.0             73            71   Sean Strickland
# ...    ...       ...      ...            ...           ...               ...
# 5799  5799      25.0     31.0             70            72      Rodrigo Ruas
# 5800  5800      30.0     36.0             68            69     Chris Brennan
# 5801  5801      24.0     33.0             72            70  Kenichi Yamamoto
# 5802  5802      32.0     31.0             62            68        Phil Johns
# 5803  5803      23.0     30.0             72            68      Daiju Takase
#
#                        red_name  blue_reach  red_reach  blue_stance  ...  \
# 1          Santiago Ponzinibbio          76         73            0  ...
# 2                   Court McGee          76         75            0  ...
# 3                  Kamaru Usman          76         76            0  ...
# 4                 Brendan Allen          76         75            0  ...
# 5     Elizeu Zaleski dos Santos          76         73            0  ...
# ...                         ...         ...        ...          ...  ...
# 5799              Tony Fryklund          70         72            0  ...
# 5800               Gil Castillo          68         69            0  ...
# 5801               Pat Miletich          72         70            0  ...
# 5802                Fabiano Iha          62         68            1  ...
# 5803                Fabiano Iha          72         68            1  ...
#
#       blue_stk_body_abs_per_min  blue_stk_leg_abs_per_min  \
# 1                      0.818414                  0.409207
# 2                      0.798155                  0.574672
# 3                      0.658506                  0.455889
# 4                      0.876289                  0.839470
# 5                      0.825941                  0.752524
# ...                         ...                       ...
# 5799                   0.000000                  0.000000
# 5800                   0.000000                  0.000000
# 5801                   0.000000                  0.000000
# 5802                   0.000000                  0.000000
# 5803                   0.000000                  0.000000
#
#       blue_stk_dist_abs_per_min  blue_stk_clch_abs_per_min  \
# 1                      2.404092                   0.051151
# 2                      2.660518                   0.223484
# 3                      2.596032                   0.189954
# 4                      3.475700                   0.176730
# 5                      2.835730                   0.220251
# ...                         ...                        ...
# 5799                   0.000000                   0.000000
# 5800                   0.000000                   0.000000
# 5801                   0.000000                   0.000000
# 5802                   0.000000                   0.000000
# 5803                   0.000000                   0.000000
#
#       blue_stk_gnd_abs_per_min  blue_reach_dif  blue_height_dif  winner  \
# 1                     0.000000               3                1     red
# 2                     0.553388               1                2    blue
# 3                     0.164626               0                1     red
# 4                     0.427099               1               -1    blue
# 5                     0.477210               3                2     red
# ...                        ...             ...              ...     ...
# 5799                  0.000000              -2               -2     red
# 5800                  0.000000              -1               -1     red
# 5801                  0.000000               2                2     red
# 5802                  0.000000              -6               -6     red
# 5803                  0.000000               4                4     red
#
#       weight_class  title_fight
# 1                8            0
# 2                8            0
# 3                8            0
# 4                0            0
# 5                8            0
# ...            ...          ...
# 5799             7            0
# 5800             8            0
# 5801             8            1
# 5802             8            0
# 5803             8            0
#
# [5793 rows x 178 columns]

# %%
# X = df.drop(columns=["lev1", "winner", "red_name", "blue_name"])
# y = df["winner"]
# feature_names = X.columns

# %%
df["winner"].value_counts()
# Out:
# red     3798
# blue    1995
# Name: winner, dtype: int64

# %%
# Separate majority and minority classes
df_majority = df[df.winner=="red"]
df_minority = df[df.winner=="blue"]
 
# Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=3798,    # to match majority class
                                 random_state=123) # reproducible results
 
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])
 
# Display new class counts
df_upsampled.winner.value_counts()
# 1    576
# 0    576
# Name: balance, dtype: int64
# Out:
# red     3798
# blue    3798
# Name: winner, dtype: int64

# %%
# Separate input features (X) and target variable (y)
y = df_upsampled.winner
X = df_upsampled.drop(columns=["lev1", "winner", "red_name", "blue_name"], axis=1)
feature_names = X.columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=200, activation='relu', input_dim=174)) 
model.add(Dense(units=200, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               35000
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               40200
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 75,602
# Trainable params: 75,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=200,
    shuffle=True,
    verbose=1
)
# Out:
# Train on 5697 samples
# Epoch 1/200
# 5697/5697 [==============================] - 1s 192us/sample - loss: 0.6694 - accuracy: 0.5831
# Epoch 2/200
# 5697/5697 [==============================] - 0s 81us/sample - loss: 0.6448 - accuracy: 0.6205
# Epoch 3/200
# 5697/5697 [==============================] - 0s 77us/sample - loss: 0.6400 - accuracy: 0.6302
# Epoch 4/200
# 5697/5697 [==============================] - 0s 78us/sample - loss: 0.6218 - accuracy: 0.6398
# Epoch 5/200
# 5697/5697 [==============================] - 0s 74us/sample - loss: 0.6089 - accuracy: 0.6560
# Epoch 6/200
# 5697/5697 [==============================] - 0s 69us/sample - loss: 0.6008 - accuracy: 0.6653
# Epoch 7/200
# 5697/5697 [==============================] - 0s 72us/sample - loss: 0.5872 - accuracy: 0.6795
# Epoch 8/200
# 5697/5697 [==============================] - 0s 76us/sample - loss: 0.5713 - accuracy: 0.6956
# Epoch 9/200
# 5697/5697 [==============================] - 0s 78us/sample - loss: 0.5655 - accuracy: 0.7025
# Epoch 10/200
# 5697/5697 [==============================] - 0s 72us/sample - loss: 0.5454 - accuracy: 0.7156
# Epoch 11/200
# 5697/5697 [==============================] - ETA: 0s - loss: 0.5279 - accuracy: 0.73 - 0s 70us/sample - loss: 0.5252 - accuracy: 0.7334
# Epoch 12/200
# 5697/5697 [==============================] - 0s 74us/sample - loss: 0.5217 - accuracy: 0.7341
# Epoch 13/200
# 5697/5697 [==============================] - 0s 74us/sample - loss: 0.4938 - accuracy: 0.7562
# Epoch 14/200
# 5697/5697 [==============================] - 0s 77us/sample - loss: 0.4876 - accuracy: 0.7548
# Epoch 15/200
# 5697/5697 [==============================] - 0s 77us/sample - loss: 0.4632 - accuracy: 0.7762
# Epoch 16/200
# 5697/5697 [==============================] - 0s 71us/sample - loss: 0.4386 - accuracy: 0.7890
# Epoch 17/200
# 5697/5697 [==============================] - 0s 73us/sample - loss: 0.4204 - accuracy: 0.8046s - loss: 0.4283 - accu
200
# 5697/5697 [==============================] - 0s 69us/sample - loss: 0.0158 - accuracy: 0.9953
# Epoch 181/200
# 5697/5697 [==============================] - 0s 72us/sample - loss: 0.0066 - accuracy: 0.9986
# Epoch 182/200
# 5697/5697 [==============================] - 0s 77us/sample - loss: 0.0063 - accuracy: 0.9986
# Epoch 183/200
# 5697/5697 [==============================] - 0s 77us/sample - loss: 0.0071 - accuracy: 0.9975s - loss: 0.0050 -
# Epoch 184/200
# 5697/5697 [==============================] - 0s 83us/sample - loss: 0.0071 - accuracy: 0.9977
# Epoch 185/200
# 5697/5697 [==============================] - 0s 67us/sample - loss: 0.0086 - accuracy: 0.9967
# Epoch 186/200
# 5697/5697 [==============================] - 0s 69us/sample - loss: 0.0613 - accuracy: 0.9800
# Epoch 187/200
# 5697/5697 [==============================] - 0s 75us/sample - loss: 0.0781 - accuracy: 0.9744
# Epoch 188/200
# 5697/5697 [==============================] - 0s 77us/sample - loss: 0.0242 - accuracy: 0.9921
# Epoch 189/200
# 5697/5697 [==============================] - 0s 76us/sample - loss: 0.0146 - accuracy: 0.9956
# Epoch 190/200
# 5697/5697 [==============================] - 0s 68us/sample - loss: 0.0281 - accuracy: 0.9903
# Epoch 191/200
# 5697/5697 [==============================] - 0s 72us/sample - loss: 0.0085 - accuracy: 0.9977
# Epoch 192/200
# 5697/5697 [==============================] - 0s 76us/sample - loss: 0.0060 - accuracy: 0.9979
# Epoch 193/200
# 5697/5697 [==============================] - 0s 78us/sample - loss: 0.0060 - accuracy: 0.9981
# Epoch 194/200
# 5697/5697 [==============================] - 0s 74us/sample - loss: 0.0054 - accuracy: 0.9984
# Epoch 195/200
# 5697/5697 [==============================] - 0s 71us/sample - loss: 0.0102 - accuracy: 0.9958
# Epoch 196/200
# 5697/5697 [==============================] - 0s 70us/sample - loss: 0.0097 - accuracy: 0.9967
# Epoch 197/200
# 5697/5697 [==============================] - 0s 72us/sample - loss: 0.0103 - accuracy: 0.9965
# Epoch 198/200
# 5697/5697 [==============================] - 0s 71us/sample - loss: 0.0087 - accuracy: 0.9961
# Epoch 199/200
# 5697/5697 [==============================] - 0s 72us/sample - loss: 0.0194 - accuracy: 0.9930
# Epoch 200/200
# 5697/5697 [==============================] - 0s 71us/sample - loss: 0.1762 - accuracy: 0.9417

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 1899/1899 - 0s - loss: 1.5279 - accuracy: 0.7730
# Normal Neural Network - Loss: 1.527875536457371, Accuracy: 0.7730384469032288

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)

# %%
d = {'prediction' : prediction_labels, 
     'actual' : y_test}

# %%
predictions_df = pd.DataFrame(data=d)
predictions_df.sample(30)
# Out:
#      prediction actual
# 4127       blue   blue
# 1676        red    red
# 1272       blue   blue
# 1619        red    red
# 981        blue   blue
# 4279       blue   blue
# 4427       blue   blue
# 3319        red   blue
# 427        blue    red
# 1034        red    red
# 3417       blue   blue
# 5206       blue   blue
# 4643        red    red
# 3562       blue   blue
# 5670        red    red
# 4605        red    red
# 1740       blue   blue
# 1901        red    red
# 4965        red    red
# 383        blue   blue
# 552        blue    red
# 579         red   blue
# 3031       blue   blue
# 4269       blue    red
# 299         red    red
# 4064       blue    red
# 5523       blue    red
# 573         red   blue
# 2991        red    red
# 217        blue   blue

# %%
model.save("../saved_models/neural_up_model.h5")
