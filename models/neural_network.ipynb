# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import feature_extraction, model_selection, naive_bayes, pipeline, manifold, preprocessing, metrics
from tensorflow.keras import models, layers, preprocessing as kprocessing
from tensorflow.keras import backend as K
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
import pickle

# %%
big_df = pd.read_csv("../data/big_df.csv")
big_df
# Out:
#       lev1  blue_age  red_age  blue_heightIN  red_heightIN         blue_name  \
# 0        0      30.0     37.0           73.0          72.0   Sean Strickland
# 1        1      24.0     28.0           73.0          72.0   Sean Strickland
# 2        2      27.0     33.0           73.0          71.0   Sean Strickland
# 3        3      26.0     30.0           73.0          72.0   Sean Strickland
# 4        4      30.0     25.0           73.0          74.0   Sean Strickland
# ...    ...       ...      ...            ...           ...               ...
# 5803  5803      25.0     31.0           70.0          72.0      Rodrigo Ruas
# 5804  5804      30.0     36.0           68.0          69.0     Chris Brennan
# 5805  5805      24.0     33.0           72.0          70.0  Kenichi Yamamoto
# 5806  5806      32.0     31.0           62.0          68.0        Phil Johns
# 5807  5807      23.0     30.0           72.0          68.0      Daiju Takase
#
#                   red_name  blue_reach  red_reach blue_stance  ...  \
# 0               Uriah Hall        76.0       79.0    Orthodox  ...
# 1     Santiago Ponzinibbio        76.0       73.0    Orthodox  ...
# 2              Court McGee        76.0       75.0    Orthodox  ...
# 3             Kamaru Usman        76.0       76.0    Orthodox  ...
# 4            Brendan Allen        76.0       75.0    Orthodox  ...
# ...                    ...         ...        ...         ...  ...
# 5803         Tony Fryklund        70.0       72.0    Orthodox  ...
# 5804          Gil Castillo        68.0       69.0    Orthodox  ...
# 5805          Pat Miletich        72.0       70.0    Orthodox  ...
# 5806           Fabiano Iha        62.0       68.0    Southpaw  ...
# 5807           Fabiano Iha        72.0       68.0    Southpaw  ...
#
#      blue_stk_gnd_per_min  blue_stk_head_abs_per_min  \
# 0                0.368644                   2.510593
# 1                0.000000                   1.227621
# 2                0.553388                   2.064562
# 3                0.164626                   1.836218
# 4                0.427099                   2.363770
# ...                   ...                        ...
# 5803             0.000000                   0.000000
# 5804             0.000000                   0.000000
# 5805             0.000000                   0.000000
# 5806             0.000000                   0.000000
# 5807             0.000000                   0.000000
#
#       blue_stk_body_abs_per_min  blue_stk_leg_abs_per_min  \
# 0                      0.978814                  0.889831
# 1                      0.818414                  0.409207
# 2                      0.798155                  0.574672
# 3                      0.658506                  0.455889
# 4                      0.876289                  0.839470
# ...                         ...                       ...
# 5803                   0.000000                  0.000000
# 5804                   0.000000                  0.000000
# 5805                   0.000000                  0.000000
# 5806                   0.000000                  0.000000
# 5807                   0.000000                  0.000000
#
#       blue_stk_dist_abs_per_min  blue_stk_clch_abs_per_min  \
# 0                      3.851695                   0.158898
# 1                      2.404092                   0.051151
# 2                      2.660518                   0.223484
# 3                      2.596032                   0.189954
# 4                      3.475700                   0.176730
# ...                         ...                        ...
# 5803                   0.000000                   0.000000
# 5804                   0.000000                   0.000000
# 5805                   0.000000                   0.000000
# 5806                   0.000000                   0.000000
# 5807                   0.000000                   0.000000
#
#       blue_stk_gnd_abs_per_min  blue_reach_dif  blue_height_dif  winner
# 0                     0.368644            -3.0              1.0     tbd
# 1                     0.000000             3.0              1.0     red
# 2                     0.553388             1.0              2.0    blue
# 3                     0.164626             0.0              1.0     red
# 4                     0.427099             1.0             -1.0    blue
# ...                        ...             ...              ...     ...
# 5803                  0.000000            -2.0             -2.0     red
# 5804                  0.000000            -1.0             -1.0     red
# 5805                  0.000000             2.0              2.0     red
# 5806                  0.000000            -6.0             -6.0     red
# 5807                  0.000000             4.0              4.0     red
#
# [5808 rows x 178 columns]

# %%
df = big_df[big_df["winner"] != "tbd"]
df
# Out:
#       lev1  blue_age  red_age  blue_heightIN  red_heightIN         blue_name  \
# 1        1      24.0     28.0           73.0          72.0   Sean Strickland
# 2        2      27.0     33.0           73.0          71.0   Sean Strickland
# 3        3      26.0     30.0           73.0          72.0   Sean Strickland
# 4        4      30.0     25.0           73.0          74.0   Sean Strickland
# 5        5      27.0     31.0           73.0          71.0   Sean Strickland
# ...    ...       ...      ...            ...           ...               ...
# 5803  5803      25.0     31.0           70.0          72.0      Rodrigo Ruas
# 5804  5804      30.0     36.0           68.0          69.0     Chris Brennan
# 5805  5805      24.0     33.0           72.0          70.0  Kenichi Yamamoto
# 5806  5806      32.0     31.0           62.0          68.0        Phil Johns
# 5807  5807      23.0     30.0           72.0          68.0      Daiju Takase
#
#                        red_name  blue_reach  red_reach blue_stance  ...  \
# 1          Santiago Ponzinibbio        76.0       73.0    Orthodox  ...
# 2                   Court McGee        76.0       75.0    Orthodox  ...
# 3                  Kamaru Usman        76.0       76.0    Orthodox  ...
# 4                 Brendan Allen        76.0       75.0    Orthodox  ...
# 5     Elizeu Zaleski dos Santos        76.0       73.0    Orthodox  ...
# ...                         ...         ...        ...         ...  ...
# 5803              Tony Fryklund        70.0       72.0    Orthodox  ...
# 5804               Gil Castillo        68.0       69.0    Orthodox  ...
# 5805               Pat Miletich        72.0       70.0    Orthodox  ...
# 5806                Fabiano Iha        62.0       68.0    Southpaw  ...
# 5807                Fabiano Iha        72.0       68.0    Southpaw  ...
#
#      blue_stk_gnd_per_min  blue_stk_head_abs_per_min  \
# 1                0.000000                   1.227621
# 2                0.553388                   2.064562
# 3                0.164626                   1.836218
# 4                0.427099                   2.363770
# 5                0.477210                   1.954726
# ...                   ...                        ...
# 5803             0.000000                   0.000000
# 5804             0.000000                   0.000000
# 5805             0.000000                   0.000000
# 5806             0.000000                   0.000000
# 5807             0.000000                   0.000000
#
#       blue_stk_body_abs_per_min  blue_stk_leg_abs_per_min  \
# 1                      0.818414                  0.409207
# 2                      0.798155                  0.574672
# 3                      0.658506                  0.455889
# 4                      0.876289                  0.839470
# 5                      0.825941                  0.752524
# ...                         ...                       ...
# 5803                   0.000000                  0.000000
# 5804                   0.000000                  0.000000
# 5805                   0.000000                  0.000000
# 5806                   0.000000                  0.000000
# 5807                   0.000000                  0.000000
#
#       blue_stk_dist_abs_per_min  blue_stk_clch_abs_per_min  \
# 1                      2.404092                   0.051151
# 2                      2.660518                   0.223484
# 3                      2.596032                   0.189954
# 4                      3.475700                   0.176730
# 5                      2.835730                   0.220251
# ...                         ...                        ...
# 5803                   0.000000                   0.000000
# 5804                   0.000000                   0.000000
# 5805                   0.000000                   0.000000
# 5806                   0.000000                   0.000000
# 5807                   0.000000                   0.000000
#
#       blue_stk_gnd_abs_per_min  blue_reach_dif  blue_height_dif  winner
# 1                     0.000000             3.0              1.0     red
# 2                     0.553388             1.0              2.0    blue
# 3                     0.164626             0.0              1.0     red
# 4                     0.427099             1.0             -1.0    blue
# 5                     0.477210             3.0              2.0     red
# ...                        ...             ...              ...     ...
# 5803                  0.000000            -2.0             -2.0     red
# 5804                  0.000000            -1.0             -1.0     red
# 5805                  0.000000             2.0              2.0     red
# 5806                  0.000000            -6.0             -6.0     red
# 5807                  0.000000             4.0              4.0     red
#
# [5793 rows x 178 columns]

# %%
number = LabelEncoder()
# data['red_name'] = number.fit_transform(data['red_name'].astype('str'))
# data['blue_name'] = number.fit_transform(data['blue_name'].astype('str'))
df['red_stance'] = number.fit_transform(df['red_stance'].astype('str'))
df['blue_stance'] = number.fit_transform(df['blue_stance'].astype('str'))
df
# Out:
# <ipython-input-4-dc2a0363b7f8>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['red_stance'] = number.fit_transform(df['red_stance'].astype('str'))
# <ipython-input-4-dc2a0363b7f8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['blue_stance'] = number.fit_transform(df['blue_stance'].astype('str'))
#       lev1  blue_age  red_age  blue_heightIN  red_heightIN         blue_name  \
# 1        1      24.0     28.0           73.0          72.0   Sean Strickland
# 2        2      27.0     33.0           73.0          71.0   Sean Strickland
# 3        3      26.0     30.0           73.0          72.0   Sean Strickland
# 4        4      30.0     25.0           73.0          74.0   Sean Strickland
# 5        5      27.0     31.0           73.0          71.0   Sean Strickland
# ...    ...       ...      ...            ...           ...               ...
# 5803  5803      25.0     31.0           70.0          72.0      Rodrigo Ruas
# 5804  5804      30.0     36.0           68.0          69.0     Chris Brennan
# 5805  5805      24.0     33.0           72.0          70.0  Kenichi Yamamoto
# 5806  5806      32.0     31.0           62.0          68.0        Phil Johns
# 5807  5807      23.0     30.0           72.0          68.0      Daiju Takase
#
#                        red_name  blue_reach  red_reach  blue_stance  ...  \
# 1          Santiago Ponzinibbio        76.0       73.0            0  ...
# 2                   Court McGee        76.0       75.0            0  ...
# 3                  Kamaru Usman        76.0       76.0            0  ...
# 4                 Brendan Allen        76.0       75.0            0  ...
# 5     Elizeu Zaleski dos Santos        76.0       73.0            0  ...
# ...                         ...         ...        ...          ...  ...
# 5803              Tony Fryklund        70.0       72.0            0  ...
# 5804               Gil Castillo        68.0       69.0            0  ...
# 5805               Pat Miletich        72.0       70.0            0  ...
# 5806                Fabiano Iha        62.0       68.0            1  ...
# 5807                Fabiano Iha        72.0       68.0            1  ...
#
#       blue_stk_gnd_per_min  blue_stk_head_abs_per_min  \
# 1                 0.000000                   1.227621
# 2                 0.553388                   2.064562
# 3                 0.164626                   1.836218
# 4                 0.427099                   2.363770
# 5                 0.477210                   1.954726
# ...                    ...                        ...
# 5803              0.000000                   0.000000
# 5804              0.000000                   0.000000
# 5805              0.000000                   0.000000
# 5806              0.000000                   0.000000
# 5807              0.000000                   0.000000
#
#       blue_stk_body_abs_per_min  blue_stk_leg_abs_per_min  \
# 1                      0.818414                  0.409207
# 2                      0.798155                  0.574672
# 3                      0.658506                  0.455889
# 4                      0.876289                  0.839470
# 5                      0.825941                  0.752524
# ...                         ...                       ...
# 5803                   0.000000                  0.000000
# 5804                   0.000000                  0.000000
# 5805                   0.000000                  0.000000
# 5806                   0.000000                  0.000000
# 5807                   0.000000                  0.000000
#
#       blue_stk_dist_abs_per_min  blue_stk_clch_abs_per_min  \
# 1                      2.404092                   0.051151
# 2                      2.660518                   0.223484
# 3                      2.596032                   0.189954
# 4                      3.475700                   0.176730
# 5                      2.835730                   0.220251
# ...                         ...                        ...
# 5803                   0.000000                   0.000000
# 5804                   0.000000                   0.000000
# 5805                   0.000000                   0.000000
# 5806                   0.000000                   0.000000
# 5807                   0.000000                   0.000000
#
#       blue_stk_gnd_abs_per_min  blue_reach_dif  blue_height_dif  winner
# 1                     0.000000             3.0              1.0     red
# 2                     0.553388             1.0              2.0    blue
# 3                     0.164626             0.0              1.0     red
# 4                     0.427099             1.0             -1.0    blue
# 5                     0.477210             3.0              2.0     red
# ...                        ...             ...              ...     ...
# 5803                  0.000000            -2.0             -2.0     red
# 5804                  0.000000            -1.0             -1.0     red
# 5805                  0.000000             2.0              2.0     red
# 5806                  0.000000            -6.0             -6.0     red
# 5807                  0.000000             4.0              4.0     red
#
# [5793 rows x 178 columns]

# %%
# X = df.drop(columns=["lev1", "winner", "red_name", "blue_name"])
# y = df["winner"]
# feature_names = X.columns

# %%
df["winner"].value_counts()
# Out:
# red     3798
# blue    1995
# Name: winner, dtype: int64

# %%
# Separate majority and minority classes
df_majority = df[df.winner=="red"]
df_minority = df[df.winner=="blue"]
 
# Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=3798,    # to match majority class
                                 random_state=123) # reproducible results
 
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])
 
# Display new class counts
df_upsampled.winner.value_counts()
# 1    576
# 0    576
# Name: balance, dtype: int64
# Out:
# blue    3798
# red     3798
# Name: winner, dtype: int64

# %%
# Separate input features (X) and target variable (y)
y = df_upsampled.winner
X = df_upsampled.drop(columns=["lev1", "winner", "red_name", "blue_name"], axis=1)
feature_names = X.columns

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)


# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=200, activation='relu', input_dim=174)) 
model.add(Dense(units=200, activation='relu'))
model.add(Dense(units=2, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               35000
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               40200
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 402
# =================================================================
# Total params: 75,602
# Trainable params: 75,602
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=200,
    shuffle=True,
    verbose=1
)
# Out:
# Epoch 1/200
# 179/179 [==============================] - 1s 2ms/step - loss: 0.6743 - accuracy: 0.5728
# Epoch 2/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.6478 - accuracy: 0.6203
# Epoch 3/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.6371 - accuracy: 0.6312
# Epoch 4/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.6288 - accuracy: 0.6405
# Epoch 5/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.6078 - accuracy: 0.6665
# Epoch 6/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.6033 - accuracy: 0.6689
# Epoch 7/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.5884 - accuracy: 0.6767
# Epoch 8/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.5704 - accuracy: 0.6991
# Epoch 9/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.5549 - accuracy: 0.7121
# Epoch 10/200
# 179/179 [==============================] - 1s 3ms/step - loss: 0.5509 - accuracy: 0.7114
# Epoch 11/200
# 179/179 [==============================] - 1s 3ms/step - loss: 0.5276 - accuracy: 0.7304
# Epoch 12/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.5181 - accuracy: 0.7416
# Epoch 13/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.5077 - accuracy: 0.7464
# Epoch 14/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7427
# Epoch 15/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.4710 - accuracy: 0.7708
# Epoch 16/200
# 179/179 [==============================] - 1s 3ms/step - loss: 0.4700 - accuracy: 0.7692
# Epoch 17/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.4385 - accuracy: 0.7850
# Epoch 18/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.4397 - accuracy: 0.7888
# Epoch 19/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.3958 - accuracy: 0.8160
# Epoch 20/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.3680 - accuracy: 0.8285
# Epoch 21/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.3684 - accuracy: 0.8273
# Epoch 22/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.3499 - accuracy: 0.8404
# Epoch 23/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.3197 - accuracy: 0.8573
# Epoch 24/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.2985 - accuracy: 0.8664
# Epoch 25/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.2720 - accuracy: 0.8836
# Epoch 26/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.2782 - accuracy: 0.8789
# Epoch 27/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.9008
# Epoch 28/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.2300 - accuracy: 0.9021
# Epoch 29/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9110
# Epoch 30/200
# 179/179 [==============================] - 1s 3ms/step - loss: 0.2058 - accuracy: 0.9136
# Epoch 31/200
# 179/179 [==============================] - 1s 3ms/step - loss: 0.1927 - accuracy: 0.9217
# Epoch 32/200
# 179/179 [==============================] - 1s 4ms/step - loss: 0.1651 - accuracy: 0.9347
# Epoch 33/200
# 179/179 [==============================] - 1s 5ms/step - loss: 0.2154 - accuracy: 0.9112
# Epoch 34/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.1593 - accuracy: 0.9382
# Epoch 35/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.1418 - accuracy: 0.9461
# Epoch 36/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1280 - accuracy: 0.9524
# Epoch 37/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1193 - accuracy: 0.9559
# Epoch 38/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1253 - accuracy: 0.9500
# Epoch 39/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9603
# Epoch 40/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 0.9682
# Epoch 41/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1073 - accuracy: 0.9628
# Epoch 42/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0961 - accuracy: 0.9658
# Epoch 43/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0974 - accuracy: 0.9656
# Epoch 44/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0902 - accuracy: 0.9679
# Epoch 45/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0800 - accuracy: 0.9712
# Epoch 46/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0767 - accuracy: 0.9758
# Epoch 47/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1407 - accuracy: 0.9433
# Epoch 48/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.2043 - accuracy: 0.9245
# Epoch 49/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0918 - accuracy: 0.9665
# Epoch 50/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.9777
# Epoch 51/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0549 - accuracy: 0.9823
# Epoch 52/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0519 - accuracy: 0.9858
# Epoch 53/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9865
# Epoch 54/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0639 - accuracy: 0.9774
# Epoch 55/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0954 - accuracy: 0.9645
# Epoch 56/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0569 - accuracy: 0.9812
# Epoch 57/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9860
# Epoch 58/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0773 - accuracy: 0.9738
# Epoch 59/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 0.9779
# Epoch 60/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0524 - accuracy: 0.9805
# Epoch 61/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0470 - accuracy: 0.9826
# Epoch 62/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0509 - accuracy: 0.9824
# Epoch 63/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9500
# Epoch 64/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0470 - accuracy: 0.9821
# Epoch 65/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0419 - accuracy: 0.9853
# Epoch 66/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0463 - accuracy: 0.9846
# Epoch 67/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0644 - accuracy: 0.9772
# Epoch 68/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0412 - accuracy: 0.9861
# Epoch 69/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9905
# Epoch 70/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9918
# Epoch 71/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0657 - accuracy: 0.9754
# Epoch 72/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0999 - accuracy: 0.9628
# Epoch 73/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0429 - accuracy: 0.9851
# Epoch 74/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 0.9919
# Epoch 75/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0206 - accuracy: 0.9930
# Epoch 76/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0218 - accuracy: 0.9921
# Epoch 77/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0293 - accuracy: 0.9903
# Epoch 78/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0335 - accuracy: 0.9896
# Epoch 79/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1457 - accuracy: 0.9449
# Epoch 80/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1302 - accuracy: 0.9547
# Epoch 81/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.9623
# Epoch 82/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0414 - accuracy: 0.9875
# Epoch 83/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0438 - accuracy: 0.9851
# Epoch 84/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9900
# Epoch 85/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0221 - accuracy: 0.9916
# Epoch 86/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9918
# Epoch 87/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0865 - accuracy: 0.9682
# Epoch 88/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0673 - accuracy: 0.9765
# Epoch 89/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0508 - accuracy: 0.9819
# Epoch 90/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0261 - accuracy: 0.9912
# Epoch 91/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0256 - accuracy: 0.9910
# Epoch 92/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9940
# Epoch 93/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.9935
# Epoch 94/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0181 - accuracy: 0.9935
# Epoch 95/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9923
# Epoch 96/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.9947
# Epoch 97/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1368 - accuracy: 0.9549
# Epoch 98/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1114 - accuracy: 0.9572
# Epoch 99/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0435 - accuracy: 0.9844
# Epoch 100/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9886
# Epoch 101/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0269 - accuracy: 0.9923
# Epoch 102/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0294 - accuracy: 0.9898
# Epoch 103/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9933
# Epoch 104/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9937
# Epoch 105/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 0.9942
# Epoch 106/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9942
# Epoch 107/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 0.9933
# Epoch 108/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9935
# Epoch 109/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9935
# Epoch 110/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0190 - accuracy: 0.9919
# Epoch 111/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9947
# Epoch 112/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0149 - accuracy: 0.9944
# Epoch 113/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.2998 - accuracy: 0.8952
# Epoch 114/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.9577
# Epoch 115/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0292 - accuracy: 0.9907
# Epoch 116/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9953
# Epoch 117/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9944
# Epoch 118/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9939
# Epoch 119/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0166 - accuracy: 0.9946
# Epoch 120/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9942
# Epoch 121/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9910
# Epoch 122/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1108 - accuracy: 0.9589
# Epoch 123/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0637 - accuracy: 0.9789
# Epoch 124/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 0.9937
# Epoch 125/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9954
# Epoch 126/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0126 - accuracy: 0.9963
# Epoch 127/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9961
# Epoch 128/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0138 - accuracy: 0.9947
# Epoch 129/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 0.9954
# Epoch 130/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0855 - accuracy: 0.9666
# Epoch 131/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9586
# Epoch 132/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9895
# Epoch 133/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 0.9951
# Epoch 134/200
# 179/179 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9954
# Epoch 135/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9958
# Epoch 136/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 0.9961
# Epoch 137/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9963
# Epoch 138/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9956
# Epoch 139/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9954
# Epoch 140/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 0.9956
# Epoch 141/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9961
# Epoch 142/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9944
# Epoch 143/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9956
# Epoch 144/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1317 - accuracy: 0.9647
# Epoch 145/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1952 - accuracy: 0.9347
# Epoch 146/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0351 - accuracy: 0.9888
# Epoch 147/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0193 - accuracy: 0.9942
# Epoch 148/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9970
# Epoch 149/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9967
# Epoch 150/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9967
# Epoch 151/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 0.9954
# Epoch 152/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 0.9961
# Epoch 153/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 0.9968
# Epoch 154/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 0.9970
# Epoch 155/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9967
# Epoch 156/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 0.9972
# Epoch 157/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9916
# Epoch 158/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1666 - accuracy: 0.9387
# Epoch 159/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0345 - accuracy: 0.9896
# Epoch 160/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 0.9940
# Epoch 161/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 0.9968
# Epoch 162/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9970
# Epoch 163/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9981
# Epoch 164/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0101 - accuracy: 0.9977
# Epoch 165/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9967
# Epoch 166/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.9977
# Epoch 167/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.9972
# Epoch 168/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9974
# Epoch 169/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9968
# Epoch 170/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1397 - accuracy: 0.9612
# Epoch 171/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1068 - accuracy: 0.9656
# Epoch 172/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9935
# Epoch 173/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9984
# Epoch 174/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9979
# Epoch 175/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9974
# Epoch 176/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9972
# Epoch 177/200
# 179/179 [==============================] - 1s 3ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 178/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9984
# Epoch 179/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 0.9982
# Epoch 180/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.9982
# Epoch 181/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 0.9982
# Epoch 182/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9946
# Epoch 183/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1440 - accuracy: 0.9530
# Epoch 184/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9735
# Epoch 185/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0155 - accuracy: 0.9956
# Epoch 186/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9951
# Epoch 187/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9977
# Epoch 188/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 0.9979
# Epoch 189/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.9975
# Epoch 190/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9981
# Epoch 191/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 0.9982
# Epoch 192/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9977
# Epoch 193/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0063 - accuracy: 0.9979
# Epoch 194/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0053 - accuracy: 0.9981
# Epoch 195/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9967
# Epoch 196/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9939
# Epoch 197/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.1458 - accuracy: 0.9505
# Epoch 198/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0663 - accuracy: 0.9754
# Epoch 199/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 0.9963
# Epoch 200/200
# 179/179 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9968

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 60/60 - 0s - loss: 1.4103 - accuracy: 0.7952
# Normal Neural Network - Loss: 1.4103032350540161, Accuracy: 0.7951553463935852

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# /home/audricperger/anaconda3/envs/pyenv/lib/python3.8/site-packages/tensorflow/python/keras/engine/sequential.py:455: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
d = {'prediction' : prediction_labels, 
     'actual' : y_test}

# %%
predictions_df = pd.DataFrame(data=d)
predictions_df.sample(30)
# Out:
#      prediction actual
# 4360        red    red
# 844        blue   blue
# 2419        red    red
# 4008        red    red
# 3043       blue   blue
# 4147       blue   blue
# 4214       blue   blue
# 3986       blue    red
# 4005        red    red
# 4627        red   blue
# 2536       blue   blue
# 2120        red    red
# 2995       blue   blue
# 4331        red    red
# 1294       blue   blue
# 1043       blue   blue
# 595        blue   blue
# 797         red    red
# 4122        red    red
# 3236       blue   blue
# 580         red   blue
# 1494       blue   blue
# 397        blue   blue
# 419        blue   blue
# 2630        red    red
# 1917       blue    red
# 2205       blue   blue
# 3713       blue   blue
# 2820        red    red
# 871        blue   blue

# %%
model.save("../saved_models/neural_up_model.h5")
