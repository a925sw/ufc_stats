# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.utils import resample

# %%
# Load in our data
big_df = pd.read_csv("../data/big_df.csv")
big_df = big_df.drop(columns="lev1")
big_df
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (215,216) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       blue_CtrlDiff  red_CtrlDiff  blue_CtrlSecPerMin  red_CtrlSecPerMin  \
# 0         13.050734     -1.564451           17.343435           0.793243
# 1         -1.920177     33.809255           10.307155          36.636569
# 2        -27.700000      6.684600            2.366667          15.790182
# 3        -11.352254     -6.521814           11.385643           7.953432
# 4         -4.677060     -0.624211            1.966274          10.936316
# ...             ...           ...                 ...                ...
# 6307       0.000000      0.000000            0.000000           0.000000
# 6308       0.000000      0.000000            0.000000           0.000000
# 6309       0.000000      0.000000            0.000000           0.000000
# 6310       0.000000      0.000000            0.000000           0.000000
# 6311       0.000000      0.000000            0.000000           0.000000
#
#       blue_CtrldSecPerMin  red_CtrldSecPerMin    blue_DOB     red_DOB  \
# 0                4.292702            2.357694  1993-09-20  1991-04-21
# 1               12.227331            2.827314  1989-04-12  1994-02-20
# 2               30.066667            9.105582  1995-09-29  1987-11-28
# 3               22.737896           14.475246  1992-11-03  1988-06-20
# 4                6.643334           11.560527  1984-09-14  1978-08-24
# ...                   ...                 ...         ...         ...
# 6307             0.000000            0.000000  1900-01-01  1900-01-01
# 6308             0.000000            0.000000  1900-01-01  1900-01-01
# 6309             0.000000            0.000000  1900-01-01  1900-01-01
# 6310             0.000000            0.000000  1900-01-01  1963-08-28
# 6311             0.000000            0.000000  1975-12-04  1900-01-01
#
#       blue_KDsPer100Stk  red_KDsPer100Stk  ...  blue_SoS   red_SoS  winner  \
# 0              0.148368          1.253918  ...  0.683544  0.655172     tbd
# 1              0.753769          0.000000  ...  0.603774  0.750000     tbd
# 2              0.000000          0.000000  ...  0.600000  0.380952     tbd
# 3              1.010101          0.336984  ...  0.500000  0.557377     tbd
# 4              1.234568          0.586166  ...  0.590909  0.631902     tbd
# ...                 ...               ...  ...       ...       ...     ...
# 6307           0.000000          0.000000  ...  0.000000  0.000000     red
# 6308           0.000000          0.000000  ...  0.000000  0.000000     red
# 6309           0.000000          0.000000  ...  0.000000  0.000000     red
# 6310           0.000000          0.000000  ...  0.000000  0.000000     red
# 6311           0.000000          0.000000  ...  0.000000  0.000000     red
#
#               weight_class  title_fight                               event  \
# 0       Men's Middleweight            0  UFC Fight Night: Costa vs. Vettori
# 1        Men's Lightweight            0  UFC Fight Night: Costa vs. Vettori
# 2     Women's Bantamweight            0  UFC Fight Night: Costa vs. Vettori
# 3      Men's Featherweight            0  UFC Fight Night: Costa vs. Vettori
# 4       Men's Welterweight            0  UFC Fight Night: Costa vs. Vettori
# ...                    ...          ...                                 ...
# 6307            Openweight            0                   UFC 2: No Way Out
# 6308            Openweight            0                   UFC 2: No Way Out
# 6309            Openweight            0                   UFC 2: No Way Out
# 6310            Openweight            0                   UFC 2: No Way Out
# 6311            Openweight            0                   UFC 2: No Way Out
#
#             date      method                location  index
# 0     2021-10-23         tbd   Las Vegas, Nevada, US      0
# 1     2021-10-23         tbd   Las Vegas, Nevada, US      1
# 2     2021-10-23         tbd   Las Vegas, Nevada, US      2
# 3     2021-10-23         tbd   Las Vegas, Nevada, US      3
# 4     2021-10-23         tbd   Las Vegas, Nevada, US      4
# ...          ...         ...                     ...    ...
# 6307  1994-03-11      KO/TKO    Denver, Colorado, US   6310
# 6308  1994-03-11  Submission    Denver, Colorado, US   6311
# 6309  1994-03-11      KO/TKO    Denver, Colorado, US   6312
# 6310  1994-03-11  Submission    Denver, Colorado, US   6313
# 6311  1994-03-11  Submission    Denver, Colorado, US   6314
#
# [6312 rows x 230 columns]

# %%
# removing fights that have not taken place yet
df = big_df[big_df["winner"] != "tbd"]
df
# Out:
#       blue_CtrlDiff  red_CtrlDiff  blue_CtrlSecPerMin  red_CtrlSecPerMin  \
# 12         7.727499     10.163043           13.754351          26.630435
# 13        -7.783333     -5.288595            2.183333           5.023857
# 14         0.000000     -3.615926            0.000000          13.705309
# 15       -26.203209      7.178988            3.288770           7.295720
# 16        12.971311     -6.327078           12.971311           3.324397
# ...             ...           ...                 ...                ...
# 6307       0.000000      0.000000            0.000000           0.000000
# 6308       0.000000      0.000000            0.000000           0.000000
# 6309       0.000000      0.000000            0.000000           0.000000
# 6310       0.000000      0.000000            0.000000           0.000000
# 6311       0.000000      0.000000            0.000000           0.000000
#
#       blue_CtrldSecPerMin  red_CtrldSecPerMin    blue_DOB     red_DOB  \
# 12               6.026852           16.467391  1990-10-01  1995-03-01
# 13               9.966667           10.312452  1995-01-12  1979-02-04
# 14               0.000000           17.321235  1992-01-20  1983-08-30
# 15              29.491979            0.116732  1991-08-22  1990-02-17
# 16               0.000000            9.651475  1995-02-22  1988-06-06
# ...                   ...                 ...         ...         ...
# 6307             0.000000            0.000000  1900-01-01  1900-01-01
# 6308             0.000000            0.000000  1900-01-01  1900-01-01
# 6309             0.000000            0.000000  1900-01-01  1900-01-01
# 6310             0.000000            0.000000  1900-01-01  1963-08-28
# 6311             0.000000            0.000000  1975-12-04  1900-01-01
#
#       blue_KDsPer100Stk  red_KDsPer100Stk  ...  blue_SoS   red_SoS  winner  \
# 12             0.598802          0.520833  ...  0.466667  0.714286    blue
# 13             0.000000          0.841043  ...  0.466667  0.664975     red
# 14             0.000000          0.306435  ...  0.000000  0.636086     red
# 15             0.000000          0.729927  ...  0.571429  0.000000     red
# 16             1.851852          0.000000  ...  0.666667  0.592593     red
# ...                 ...               ...  ...       ...       ...     ...
# 6307           0.000000          0.000000  ...  0.000000  0.000000     red
# 6308           0.000000          0.000000  ...  0.000000  0.000000     red
# 6309           0.000000          0.000000  ...  0.000000  0.000000     red
# 6310           0.000000          0.000000  ...  0.000000  0.000000     red
# 6311           0.000000          0.000000  ...  0.000000  0.000000     red
#
#                weight_class  title_fight                             event  \
# 12    Women's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# 13        Men's Heavyweight            0  UFC Fight Night: Ladd vs. Dumont
# 14        Men's Lightweight            0  UFC Fight Night: Ladd vs. Dumont
# 15        Women's Flyweight            0  UFC Fight Night: Ladd vs. Dumont
# 16      Men's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# ...                     ...          ...                               ...
# 6307             Openweight            0                 UFC 2: No Way Out
# 6308             Openweight            0                 UFC 2: No Way Out
# 6309             Openweight            0                 UFC 2: No Way Out
# 6310             Openweight            0                 UFC 2: No Way Out
# 6311             Openweight            0                 UFC 2: No Way Out
#
#             date      method                location  index
# 12    2021-10-16          UD   Las Vegas, Nevada, US     14
# 13    2021-10-16          UD   Las Vegas, Nevada, US     15
# 14    2021-10-16      KO/TKO   Las Vegas, Nevada, US     16
# 15    2021-10-16          UD   Las Vegas, Nevada, US     17
# 16    2021-10-16  Submission   Las Vegas, Nevada, US     18
# ...          ...         ...                     ...    ...
# 6307  1994-03-11      KO/TKO    Denver, Colorado, US   6310
# 6308  1994-03-11  Submission    Denver, Colorado, US   6311
# 6309  1994-03-11      KO/TKO    Denver, Colorado, US   6312
# 6310  1994-03-11  Submission    Denver, Colorado, US   6313
# 6311  1994-03-11  Submission    Denver, Colorado, US   6314
#
# [6300 rows x 230 columns]

# %%
# Dropping all fights that occured before unified rules were implamented 
df["date"] = pd.to_datetime(df["date"])
df = df[df["date"] >= "November 17, 2000"]
df
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       blue_CtrlDiff  red_CtrlDiff  blue_CtrlSecPerMin  red_CtrlSecPerMin  \
# 12         7.727499     10.163043           13.754351          26.630435
# 13        -7.783333     -5.288595            2.183333           5.023857
# 14         0.000000     -3.615926            0.000000          13.705309
# 15       -26.203209      7.178988            3.288770           7.295720
# 16        12.971311     -6.327078           12.971311           3.324397
# ...             ...           ...                 ...                ...
# 6075       0.000000      0.000000            0.000000           0.000000
# 6076       0.000000      0.000000            0.000000           0.000000
# 6077      19.282219     21.601224           19.575856          25.976543
# 6078       0.000000      0.000000            0.000000           0.000000
# 6079       0.000000      0.000000            0.000000           0.000000
#
#       blue_CtrldSecPerMin  red_CtrldSecPerMin    blue_DOB     red_DOB  \
# 12               6.026852           16.467391  1990-10-01  1995-03-01
# 13               9.966667           10.312452  1995-01-12  1979-02-04
# 14               0.000000           17.321235  1992-01-20  1983-08-30
# 15              29.491979            0.116732  1991-08-22  1990-02-17
# 16               0.000000            9.651475  1995-02-22  1988-06-06
# ...                   ...                 ...         ...         ...
# 6075             0.000000            0.000000  1976-11-20  1977-11-10
# 6076             0.000000            0.000000  1974-11-12  1979-02-04
# 6077             0.293638            4.375319  1900-01-01  1974-12-06
# 6078             0.000000            0.000000  1900-01-01  1973-10-13
# 6079             0.000000            0.000000  1974-08-18  1900-01-01
#
#       blue_KDsPer100Stk  red_KDsPer100Stk  ...  blue_SoS   red_SoS  winner  \
# 12             0.598802          0.520833  ...  0.466667  0.714286    blue
# 13             0.000000          0.841043  ...  0.466667  0.664975     red
# 14             0.000000          0.306435  ...  0.000000  0.636086     red
# 15             0.000000          0.729927  ...  0.571429  0.000000     red
# 16             1.851852          0.000000  ...  0.666667  0.592593     red
# ...                 ...               ...  ...       ...       ...     ...
# 6075           0.000000          0.000000  ...  0.000000  0.000000     red
# 6076           0.000000          0.000000  ...  0.000000  0.000000     red
# 6077           0.000000          0.000000  ...  0.000000  0.000000     red
# 6078           0.000000          0.000000  ...  0.000000  0.000000     red
# 6079           0.000000          0.000000  ...  0.000000  0.000000     red
#
#                weight_class  title_fight                             event  \
# 12    Women's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# 13        Men's Heavyweight            0  UFC Fight Night: Ladd vs. Dumont
# 14        Men's Lightweight            0  UFC Fight Night: Ladd vs. Dumont
# 15        Women's Flyweight            0  UFC Fight Night: Ladd vs. Dumont
# 16      Men's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# ...                     ...          ...                               ...
# 6075      Men's Heavyweight            0               UFC 28: High Stakes
# 6076      Men's Heavyweight            0               UFC 28: High Stakes
# 6077      Men's Lightweight            0               UFC 28: High Stakes
# 6078     Men's Middleweight            0               UFC 28: High Stakes
# 6079     Men's Welterweight            0               UFC 28: High Stakes
#
#            date      method                        location  index
# 12   2021-10-16          UD           Las Vegas, Nevada, US     14
# 13   2021-10-16          UD           Las Vegas, Nevada, US     15
# 14   2021-10-16      KO/TKO           Las Vegas, Nevada, US     16
# 15   2021-10-16          UD           Las Vegas, Nevada, US     17
# 16   2021-10-16  Submission           Las Vegas, Nevada, US     18
# ...         ...         ...                             ...    ...
# 6075 2000-11-17      KO/TKO   Atlantic City, New Jersey, US   6078
# 6076 2000-11-17  Submission   Atlantic City, New Jersey, US   6079
# 6077 2000-11-17      KO/TKO   Atlantic City, New Jersey, US   6080
# 6078 2000-11-17          UD   Atlantic City, New Jersey, US   6081
# 6079 2000-11-17          UD   Atlantic City, New Jersey, US   6082
#
# [6068 rows x 230 columns]

# %%
df["red_age"] = pd.Series(df["red_age"], dtype="int")
df["blue_age"] = pd.Series(df["blue_age"], dtype="int")
df["red_heightIN"] = pd.Series(df["red_heightIN"], dtype="int")
df["blue_heightIN"] = pd.Series(df["blue_heightIN"], dtype="int")
df
# Out:
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\audri\anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#       blue_CtrlDiff  red_CtrlDiff  blue_CtrlSecPerMin  red_CtrlSecPerMin  \
# 12         7.727499     10.163043           13.754351          26.630435
# 13        -7.783333     -5.288595            2.183333           5.023857
# 14         0.000000     -3.615926            0.000000          13.705309
# 15       -26.203209      7.178988            3.288770           7.295720
# 16        12.971311     -6.327078           12.971311           3.324397
# ...             ...           ...                 ...                ...
# 6075       0.000000      0.000000            0.000000           0.000000
# 6076       0.000000      0.000000            0.000000           0.000000
# 6077      19.282219     21.601224           19.575856          25.976543
# 6078       0.000000      0.000000            0.000000           0.000000
# 6079       0.000000      0.000000            0.000000           0.000000
#
#       blue_CtrldSecPerMin  red_CtrldSecPerMin    blue_DOB     red_DOB  \
# 12               6.026852           16.467391  1990-10-01  1995-03-01
# 13               9.966667           10.312452  1995-01-12  1979-02-04
# 14               0.000000           17.321235  1992-01-20  1983-08-30
# 15              29.491979            0.116732  1991-08-22  1990-02-17
# 16               0.000000            9.651475  1995-02-22  1988-06-06
# ...                   ...                 ...         ...         ...
# 6075             0.000000            0.000000  1976-11-20  1977-11-10
# 6076             0.000000            0.000000  1974-11-12  1979-02-04
# 6077             0.293638            4.375319  1900-01-01  1974-12-06
# 6078             0.000000            0.000000  1900-01-01  1973-10-13
# 6079             0.000000            0.000000  1974-08-18  1900-01-01
#
#       blue_KDsPer100Stk  red_KDsPer100Stk  ...  blue_SoS   red_SoS  winner  \
# 12             0.598802          0.520833  ...  0.466667  0.714286    blue
# 13             0.000000          0.841043  ...  0.466667  0.664975     red
# 14             0.000000          0.306435  ...  0.000000  0.636086     red
# 15             0.000000          0.729927  ...  0.571429  0.000000     red
# 16             1.851852          0.000000  ...  0.666667  0.592593     red
# ...                 ...               ...  ...       ...       ...     ...
# 6075           0.000000          0.000000  ...  0.000000  0.000000     red
# 6076           0.000000          0.000000  ...  0.000000  0.000000     red
# 6077           0.000000          0.000000  ...  0.000000  0.000000     red
# 6078           0.000000          0.000000  ...  0.000000  0.000000     red
# 6079           0.000000          0.000000  ...  0.000000  0.000000     red
#
#                weight_class  title_fight                             event  \
# 12    Women's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# 13        Men's Heavyweight            0  UFC Fight Night: Ladd vs. Dumont
# 14        Men's Lightweight            0  UFC Fight Night: Ladd vs. Dumont
# 15        Women's Flyweight            0  UFC Fight Night: Ladd vs. Dumont
# 16      Men's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# ...                     ...          ...                               ...
# 6075      Men's Heavyweight            0               UFC 28: High Stakes
# 6076      Men's Heavyweight            0               UFC 28: High Stakes
# 6077      Men's Lightweight            0               UFC 28: High Stakes
# 6078     Men's Middleweight            0               UFC 28: High Stakes
# 6079     Men's Welterweight            0               UFC 28: High Stakes
#
#            date      method                        location  index
# 12   2021-10-16          UD           Las Vegas, Nevada, US     14
# 13   2021-10-16          UD           Las Vegas, Nevada, US     15
# 14   2021-10-16      KO/TKO           Las Vegas, Nevada, US     16
# 15   2021-10-16          UD           Las Vegas, Nevada, US     17
# 16   2021-10-16  Submission           Las Vegas, Nevada, US     18
# ...         ...         ...                             ...    ...
# 6075 2000-11-17      KO/TKO   Atlantic City, New Jersey, US   6078
# 6076 2000-11-17  Submission   Atlantic City, New Jersey, US   6079
# 6077 2000-11-17      KO/TKO   Atlantic City, New Jersey, US   6080
# 6078 2000-11-17          UD   Atlantic City, New Jersey, US   6081
# 6079 2000-11-17          UD   Atlantic City, New Jersey, US   6082
#
# [6068 rows x 230 columns]

# %%
df = df[df["red_age"] < 75]
df = df[df["blue_age"] < 75]
df
# Out:
#       blue_CtrlDiff  red_CtrlDiff  blue_CtrlSecPerMin  red_CtrlSecPerMin  \
# 12         7.727499     10.163043           13.754351          26.630435
# 13        -7.783333     -5.288595            2.183333           5.023857
# 14         0.000000     -3.615926            0.000000          13.705309
# 15       -26.203209      7.178988            3.288770           7.295720
# 16        12.971311     -6.327078           12.971311           3.324397
# ...             ...           ...                 ...                ...
# 6072      32.600000      3.012552           42.300000           4.447101
# 6073      16.957746      0.000000           17.943662           0.000000
# 6074      -5.681330      0.000000            5.793991           0.000000
# 6075       0.000000      0.000000            0.000000           0.000000
# 6076       0.000000      0.000000            0.000000           0.000000
#
#       blue_CtrldSecPerMin  red_CtrldSecPerMin    blue_DOB     red_DOB  \
# 12               6.026852           16.467391  1990-10-01  1995-03-01
# 13               9.966667           10.312452  1995-01-12  1979-02-04
# 14               0.000000           17.321235  1992-01-20  1983-08-30
# 15              29.491979            0.116732  1991-08-22  1990-02-17
# 16               0.000000            9.651475  1995-02-22  1988-06-06
# ...                   ...                 ...         ...         ...
# 6072             9.700000            1.434549  1971-01-18  1969-12-17
# 6073             0.985915            0.000000  1971-08-10  1963-06-22
# 6074            11.475322            0.000000  1961-12-13  1975-09-07
# 6075             0.000000            0.000000  1976-11-20  1977-11-10
# 6076             0.000000            0.000000  1974-11-12  1979-02-04
#
#       blue_KDsPer100Stk  red_KDsPer100Stk  ...  blue_SoS   red_SoS  winner  \
# 12             0.598802          0.520833  ...  0.466667  0.714286    blue
# 13             0.000000          0.841043  ...  0.466667  0.664975     red
# 14             0.000000          0.306435  ...  0.000000  0.636086     red
# 15             0.000000          0.729927  ...  0.571429  0.000000     red
# 16             1.851852          0.000000  ...  0.666667  0.592593     red
# ...                 ...               ...  ...       ...       ...     ...
# 6072           0.000000          0.000000  ...  0.000000  0.333333     red
# 6073           0.000000          0.000000  ...  0.833333  1.000000     red
# 6074           0.000000          0.000000  ...  0.760000  0.000000     red
# 6075           0.000000          0.000000  ...  0.000000  0.000000     red
# 6076           0.000000          0.000000  ...  0.000000  0.000000     red
#
#                weight_class  title_fight                             event  \
# 12    Women's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# 13        Men's Heavyweight            0  UFC Fight Night: Ladd vs. Dumont
# 14        Men's Lightweight            0  UFC Fight Night: Ladd vs. Dumont
# 15        Women's Flyweight            0  UFC Fight Night: Ladd vs. Dumont
# 16      Men's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# ...                     ...          ...                               ...
# 6072     Men's Middleweight            0      UFC 29: Defense of the Belts
# 6073      Men's Heavyweight            1               UFC 28: High Stakes
# 6074      Men's Heavyweight            0               UFC 28: High Stakes
# 6075      Men's Heavyweight            0               UFC 28: High Stakes
# 6076      Men's Heavyweight            0               UFC 28: High Stakes
#
#            date      method                        location  index
# 12   2021-10-16          UD           Las Vegas, Nevada, US     14
# 13   2021-10-16          UD           Las Vegas, Nevada, US     15
# 14   2021-10-16      KO/TKO           Las Vegas, Nevada, US     16
# 15   2021-10-16          UD           Las Vegas, Nevada, US     17
# 16   2021-10-16  Submission           Las Vegas, Nevada, US     18
# ...         ...         ...                             ...    ...
# 6072 2000-12-16          UD                    Tokyo, Japan   6075
# 6073 2000-11-17      KO/TKO   Atlantic City, New Jersey, US   6076
# 6074 2000-11-17          MD   Atlantic City, New Jersey, US   6077
# 6075 2000-11-17      KO/TKO   Atlantic City, New Jersey, US   6078
# 6076 2000-11-17  Submission   Atlantic City, New Jersey, US   6079
#
# [6015 rows x 230 columns]

# %%
df = df[df["red_heightIN"] < 100]
df = df[df["blue_heightIN"] < 100]
df
# Out:
#       blue_CtrlDiff  red_CtrlDiff  blue_CtrlSecPerMin  red_CtrlSecPerMin  \
# 12         7.727499     10.163043           13.754351          26.630435
# 13        -7.783333     -5.288595            2.183333           5.023857
# 14         0.000000     -3.615926            0.000000          13.705309
# 15       -26.203209      7.178988            3.288770           7.295720
# 16        12.971311     -6.327078           12.971311           3.324397
# ...             ...           ...                 ...                ...
# 6072      32.600000      3.012552           42.300000           4.447101
# 6073      16.957746      0.000000           17.943662           0.000000
# 6074      -5.681330      0.000000            5.793991           0.000000
# 6075       0.000000      0.000000            0.000000           0.000000
# 6076       0.000000      0.000000            0.000000           0.000000
#
#       blue_CtrldSecPerMin  red_CtrldSecPerMin    blue_DOB     red_DOB  \
# 12               6.026852           16.467391  1990-10-01  1995-03-01
# 13               9.966667           10.312452  1995-01-12  1979-02-04
# 14               0.000000           17.321235  1992-01-20  1983-08-30
# 15              29.491979            0.116732  1991-08-22  1990-02-17
# 16               0.000000            9.651475  1995-02-22  1988-06-06
# ...                   ...                 ...         ...         ...
# 6072             9.700000            1.434549  1971-01-18  1969-12-17
# 6073             0.985915            0.000000  1971-08-10  1963-06-22
# 6074            11.475322            0.000000  1961-12-13  1975-09-07
# 6075             0.000000            0.000000  1976-11-20  1977-11-10
# 6076             0.000000            0.000000  1974-11-12  1979-02-04
#
#       blue_KDsPer100Stk  red_KDsPer100Stk  ...  blue_SoS   red_SoS  winner  \
# 12             0.598802          0.520833  ...  0.466667  0.714286    blue
# 13             0.000000          0.841043  ...  0.466667  0.664975     red
# 14             0.000000          0.306435  ...  0.000000  0.636086     red
# 15             0.000000          0.729927  ...  0.571429  0.000000     red
# 16             1.851852          0.000000  ...  0.666667  0.592593     red
# ...                 ...               ...  ...       ...       ...     ...
# 6072           0.000000          0.000000  ...  0.000000  0.333333     red
# 6073           0.000000          0.000000  ...  0.833333  1.000000     red
# 6074           0.000000          0.000000  ...  0.760000  0.000000     red
# 6075           0.000000          0.000000  ...  0.000000  0.000000     red
# 6076           0.000000          0.000000  ...  0.000000  0.000000     red
#
#                weight_class  title_fight                             event  \
# 12    Women's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# 13        Men's Heavyweight            0  UFC Fight Night: Ladd vs. Dumont
# 14        Men's Lightweight            0  UFC Fight Night: Ladd vs. Dumont
# 15        Women's Flyweight            0  UFC Fight Night: Ladd vs. Dumont
# 16      Men's Featherweight            0  UFC Fight Night: Ladd vs. Dumont
# ...                     ...          ...                               ...
# 6072     Men's Middleweight            0      UFC 29: Defense of the Belts
# 6073      Men's Heavyweight            1               UFC 28: High Stakes
# 6074      Men's Heavyweight            0               UFC 28: High Stakes
# 6075      Men's Heavyweight            0               UFC 28: High Stakes
# 6076      Men's Heavyweight            0               UFC 28: High Stakes
#
#            date      method                        location  index
# 12   2021-10-16          UD           Las Vegas, Nevada, US     14
# 13   2021-10-16          UD           Las Vegas, Nevada, US     15
# 14   2021-10-16      KO/TKO           Las Vegas, Nevada, US     16
# 15   2021-10-16          UD           Las Vegas, Nevada, US     17
# 16   2021-10-16  Submission           Las Vegas, Nevada, US     18
# ...         ...         ...                             ...    ...
# 6072 2000-12-16          UD                    Tokyo, Japan   6075
# 6073 2000-11-17      KO/TKO   Atlantic City, New Jersey, US   6076
# 6074 2000-11-17          MD   Atlantic City, New Jersey, US   6077
# 6075 2000-11-17      KO/TKO   Atlantic City, New Jersey, US   6078
# 6076 2000-11-17  Submission   Atlantic City, New Jersey, US   6079
#
# [6013 rows x 230 columns]

# %%
# Label encoder for stance and weight class
number = LabelEncoder()
# data['red_name'] = number.fit_transform(data['red_name'].astype('str'))
# data['blue_name'] = number.fit_transform(data['blue_name'].astype('str'))
df['red_stance'] = number.fit_transform(df['red_stance'].astype('str'))
df['blue_stance'] = number.fit_transform(df['blue_stance'].astype('str'))
df['weight_class'] = number.fit_transform(df['weight_class'].astype('str'))
df
# Out:
#       blue_CtrlDiff  red_CtrlDiff  blue_CtrlSecPerMin  red_CtrlSecPerMin  \
# 12         7.727499     10.163043           13.754351          26.630435
# 13        -7.783333     -5.288595            2.183333           5.023857
# 14         0.000000     -3.615926            0.000000          13.705309
# 15       -26.203209      7.178988            3.288770           7.295720
# 16        12.971311     -6.327078           12.971311           3.324397
# ...             ...           ...                 ...                ...
# 6072      32.600000      3.012552           42.300000           4.447101
# 6073      16.957746      0.000000           17.943662           0.000000
# 6074      -5.681330      0.000000            5.793991           0.000000
# 6075       0.000000      0.000000            0.000000           0.000000
# 6076       0.000000      0.000000            0.000000           0.000000
#
#       blue_CtrldSecPerMin  red_CtrldSecPerMin    blue_DOB     red_DOB  \
# 12               6.026852           16.467391  1990-10-01  1995-03-01
# 13               9.966667           10.312452  1995-01-12  1979-02-04
# 14               0.000000           17.321235  1992-01-20  1983-08-30
# 15              29.491979            0.116732  1991-08-22  1990-02-17
# 16               0.000000            9.651475  1995-02-22  1988-06-06
# ...                   ...                 ...         ...         ...
# 6072             9.700000            1.434549  1971-01-18  1969-12-17
# 6073             0.985915            0.000000  1971-08-10  1963-06-22
# 6074            11.475322            0.000000  1961-12-13  1975-09-07
# 6075             0.000000            0.000000  1976-11-20  1977-11-10
# 6076             0.000000            0.000000  1974-11-12  1979-02-04
#
#       blue_KDsPer100Stk  red_KDsPer100Stk  ...  blue_SoS   red_SoS  winner  \
# 12             0.598802          0.520833  ...  0.466667  0.714286    blue
# 13             0.000000          0.841043  ...  0.466667  0.664975     red
# 14             0.000000          0.306435  ...  0.000000  0.636086     red
# 15             0.000000          0.729927  ...  0.571429  0.000000     red
# 16             1.851852          0.000000  ...  0.666667  0.592593     red
# ...                 ...               ...  ...       ...       ...     ...
# 6072           0.000000          0.000000  ...  0.000000  0.333333     red
# 6073           0.000000          0.000000  ...  0.833333  1.000000     red
# 6074           0.000000          0.000000  ...  0.760000  0.000000     red
# 6075           0.000000          0.000000  ...  0.000000  0.000000     red
# 6076           0.000000          0.000000  ...  0.000000  0.000000     red
#
#       weight_class  title_fight                             event       date  \
# 12              10            0  UFC Fight Night: Ladd vs. Dumont 2021-10-16
# 13               4            0  UFC Fight Night: Ladd vs. Dumont 2021-10-16
# 14               6            0  UFC Fight Night: Ladd vs. Dumont 2021-10-16
# 15              11            0  UFC Fight Night: Ladd vs. Dumont 2021-10-16
# 16               2            0  UFC Fight Night: Ladd vs. Dumont 2021-10-16
# ...            ...          ...                               ...        ...
# 6072             7            0      UFC 29: Defense of the Belts 2000-12-16
# 6073             4            1               UFC 28: High Stakes 2000-11-17
# 6074             4            0               UFC 28: High Stakes 2000-11-17
# 6075             4            0               UFC 28: High Stakes 2000-11-17
# 6076             4            0               UFC 28: High Stakes 2000-11-17
#
#           method                        location  index
# 12            UD           Las Vegas, Nevada, US     14
# 13            UD           Las Vegas, Nevada, US     15
# 14        KO/TKO           Las Vegas, Nevada, US     16
# 15            UD           Las Vegas, Nevada, US     17
# 16    Submission           Las Vegas, Nevada, US     18
# ...          ...                             ...    ...
# 6072          UD                    Tokyo, Japan   6075
# 6073      KO/TKO   Atlantic City, New Jersey, US   6076
# 6074          MD   Atlantic City, New Jersey, US   6077
# 6075      KO/TKO   Atlantic City, New Jersey, US   6078
# 6076  Submission   Atlantic City, New Jersey, US   6079
#
# [6013 rows x 230 columns]

# %%
# removing draws and no contests 
df = df[df["winner"] != "Draw"] # it's arguable draws are useful datapoints, but I choose to remove them
df = df[df["winner"] != "NC"] # no contests however are not useful datapoints
df["winner"].value_counts()
# Out:
# red     3863
# blue    2042
# Name: winner, dtype: int64

# %%
df = df[df["method"] != "DQ"]
df["method"].value_counts()
# Out:
# UD            2156
# KO/TKO        1962
# Submission    1150
# SD             576
# MD              43
# Name: method, dtype: int64

# %%
df["winner"].value_counts()
# Out:
# red     3851
# blue    2036
# Name: winner, dtype: int64

# %%
# Separate majority and minority classes
df_majority = df[df.winner=="red"]
df_minority = df[df.winner=="blue"]
 
# Upsample minority class
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=len(df_majority), # to match majority class
                                 random_state=123) # reproducible results
 
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])
 
# Display new class counts
df_upsampled.winner.value_counts()
# Out:
# red     3851
# blue    3851
# Name: winner, dtype: int64

# %%
# Separate input features (X) and target variable (y)
y = df_upsampled.winner
X = df_upsampled.drop(columns=["winner", "red_name", "blue_name", "date", "event", "red_DOB", "blue_DOB", "method", \
                               "location", "red_nickname", "blue_nickname", "red_weight", "blue_weight", "index"], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X)
# Transform the training and testing data using the X_scaler and y_scaler models
X_scaled = X_scaler.transform(X)

# %%
lr = LogisticRegression(solver="liblinear", random_state=42)
rf = RandomForestClassifier(max_features=None, random_state=42)
knn = KNeighborsClassifier(n_neighbors=13)

# %%
vc = VotingClassifier([("clf1", lr), ("clf2", rf), ("clf3", knn)])
cross_val_score(vc, X_scaled, y).mean()
# Out:
# 0.6868576653716173

# %%
params = {"voting" : ["hard", "soft"],
         "weights" : [(1,1,1), (2,1,1), (1,2,1), (1,1,2)]}

# %%
grid = GridSearchCV(vc, params)
grid.fit(X_scaled, y)
grid.best_params_
# Out:
# {'voting': 'soft', 'weights': (1, 2, 1)}

# %%
grid.best_score_
# Out:
# 0.7332084917029758
