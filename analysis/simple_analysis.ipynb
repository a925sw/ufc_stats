# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
fighters_df = pd.read_csv("../data/fighters_df.csv")
fighters_df = fighters_df.drop(columns="Unnamed: 0")
fighters_df
# Out:
#                     name         DOB   age  heightIN  reach    stance  \
# 0             Aalon Cruz  1989-09-20  31.0        72     78    Switch
# 1            Aaron Brink  1974-11-12  26.0        75     75  Orthodox
# 2         Aaron Phillips  1989-08-05  31.0        69     71  Southpaw
# 3            Aaron Riley  1980-12-09  33.0        68     69  Southpaw
# 4             Aaron Rosa  1983-05-28  29.0        76     77  Orthodox
# ...                  ...         ...   ...       ...    ...       ...
# 1968  Zhalgas Zhumagulov  1988-08-29  33.0        64     66    Switch
# 1969        Zhang Lipeng  1990-03-10  25.0        71     71  Southpaw
# 1970       Zhang Tiequan  1978-07-25  34.0        68     69  Orthodox
# 1971         Zhang Weili  1989-08-13  32.0        64     63    Switch
# 1972    Zubaira Tukhugov  1991-01-15  30.0        68     68  Orthodox
#
#                  weightclass  sumTotStksLnd  sumTotStksAtt  sumSigStksLnd  \
# ...

# %%
ax1 = fighters_df.plot.scatter(x='SigStkPerMin',
                      y='SigStkAbsPerMin')
ax1
# Out:
# <AxesSubplot:xlabel='SigStkPerMin', ylabel='SigStkAbsPerMin'>

# %%
qualifying_df = fighters_df[fighters_df["wins"] + fighters_df["losses"] >= 5]
qualifying_df
# Out:
#                       name         DOB   age  heightIN  reach    stance  \
# 3              Aaron Riley  1980-12-09  33.0        68     69  Southpaw
# 5            Aaron Simpson  1974-07-20  38.0        72     73  Orthodox
# 7     Abdul Razak Alhassan  1985-08-11  36.0        70     73  Orthodox
# 9            Abel Trujillo  1983-09-18  34.0        68     70  Orthodox
# 19         Adriano Martins  1982-12-16  35.0        70     72  Southpaw
# ...                    ...         ...   ...       ...    ...       ...
# 1962         Zach Makovsky  1983-04-19  34.0        64     64  Southpaw
# 1963          Zak Cummings  1984-08-02  36.0        72     75  Southpaw
# 1964             Zak Ottow  1986-12-22  32.0        71     72  Orthodox
# 1971           Zhang Weili  1989-08-13  32.0        64     63    Switch
# 1972      Zubaira Tukhugov  1991-01-15  30.0        68     68  Orthodox
#
#               weightclass  sumTotStksLnd  sumTotStksAtt  sumSigStksLnd  \
# ...

# %%
qualifying_df.sort_values(by="SigStkPerMinDiff", ascending=False).head(20)
# Out:
#                        name         DOB   age  heightIN  reach    stance  \
# 1691          Sean O'Malley  1994-10-24  27.0        71     72    Switch
# 394       Cristiane Justino  1985-07-09  34.0        68     68  Orthodox
# 264          Cain Velasquez  1982-07-28  37.0        73     77  Orthodox
# 1794         Tatiana Suarez  1990-12-19  28.0        65     66  Southpaw
# 887      Joanna Jedrzejczyk  1987-08-18  33.0        66     65  Orthodox
# 1832            Todd Duffee  1985-12-06  30.0        75     78  Orthodox
# 1493               Petr Yan  1993-02-11  27.0        67     67    Switch
# 438        Daniel Rodriguez  1986-12-31  35.0        73     74  Southpaw
# 355              Ciryl Gane  1990-04-12  31.0        76     81  Orthodox
# 79        Aljamain Sterling  1989-07-31  31.0        67     71  Orthodox
# 937          Johnny Bedford  1983-01-06  32.0        70     71  Orthodox
# 66    Alexander Volkanovski  1988-09-29  32.0        66     71  Orthodox
# ...

# %%
qualifying_df.sort_values(by="TotStkPerMinDiff", ascending=False).head(20)
# Out:
#                         name         DOB   age  heightIN  reach    stance  \
# 264           Cain Velasquez  1982-07-28  37.0        73     77  Orthodox
# 808             Jared Gordon  1988-09-06  32.0        69     68  Orthodox
# 296             Chael Sonnen  1977-04-03  37.0        73     73  Southpaw
# 1937         Yana Kunitskaya  1989-11-11  32.0        66     68  Orthodox
# 1313       Merab Dvalishvili  1991-01-10  30.0        66     68  Orthodox
# 945                Jon Fitch  1978-02-24  35.0        72     74  Orthodox
# 199        Billy Quarantillo  1988-12-08  33.0        70     70  Orthodox
# 1286           Matt Lindland  1970-05-17  35.0        72     74  Southpaw
# 1055            Kamaru Usman  1987-05-11  34.0        72     76    Switch
# 1236  Marcos Rogerio de Lima  1985-06-25  36.0        73     75  Orthodox
# 1794          Tatiana Suarez  1990-12-19  28.0        65     66  Southpaw
# 809             Jared Hamman  1982-03-07  31.0        75     75  Orthodox
# ...
