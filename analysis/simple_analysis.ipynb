# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
big_df = pd.read_csv("../data/big_df.csv")
big_df
# Out:
#       lev1  blue_age  red_age  blue_heightIN  red_heightIN  \
# 0        0      29.0     38.0             72            73
# 1        1      27.0     28.0             75            77
# 2        2      31.0     31.0             72            71
# 3        3      32.0     28.0             73            75
# 4        4      26.0     27.0             68            70
# ...    ...       ...      ...            ...           ...
# 5844  5844      30.0     31.0             69            74
# 5845  5845      29.0     37.0             70            73
# 5846  5846      39.0     25.0             74            73
# 5847  5847      24.0     23.0             82            75
# 5848  5848      26.0     22.0             75            75
#
#                 blue_name            red_name  blue_reach  red_reach  \
# 0             Darren Till       Derek Brunson          74         77
# 1          Serghei Spivac        Tom Aspinall          78         78
# ...

# %%
future_fights = big_df[big_df["winner"] == "tbd"]
future_fights
# Out:
#    lev1  blue_age  red_age  blue_heightIN  red_heightIN             blue_name  \
# 0     0      29.0     38.0             72            73           Darren Till
# 1     1      27.0     28.0             75            77        Serghei Spivac
# 2     2      31.0     31.0             72            71          David Zawada
# 3     3      32.0     28.0             73            75   Khalil Rountree Jr.
# 4     4      26.0     27.0             68            70      Luigi Vendramini
# 5     5      32.0     31.0             67            64           Ji Yeon Kim
# 6     6      32.0     27.0             70            68     Liudvik Sholinian
# 7     7      26.0     32.0             69            73      Charles Jourdain
# 8     8      32.0     34.0             73            68  Marc-Andre Barriault
# 9     9      33.0     27.0             68            68          Marcelo Rojo
#
#              red_name  blue_reach  red_reach blue_stance  ...  \
# ...
